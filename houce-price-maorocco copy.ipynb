# %% [markdown]
# Dans ce projet, nous sommes intéressés par l'extraction des données associées à la construction sur le site https://www.mubawab.ma/, ainsi que l'extraction des informations qui caractérisent les constructions publiées sur le site.

# %% [markdown]
# ### 1. Installation des bibliothèques

# %%
# Décommenter les lignes pour installer les bibliothèques.

#!pip install selenium
#!pip install bs4
#!pip install pandas

# %% [markdown]
# ### 2.  Importation des bibliothèques

# %%
# Importation des bibliothèques nécessaires pour le scraping avec Selenium

# Permet de simuler des actions utilisateur (clics, mouvements de souris, etc.)
from selenium.webdriver import ActionChains 

# Permet d'utiliser le WebDriver pour contrôler un navigateur web
from selenium import webdriver

 # Permet de gérer le service ChromeDriver (non utilisé ici, mais peut être nécessaire dans certains cas)
from selenium.webdriver.chrome.service import Service 
# Permet d'interagir avec le système d'exploitation, par exemple pour gérer les chemins de fichiers
import os
# Permet de localiser des éléments sur la page web
from selenium.webdriver.common.by import By
# Permet d'ajouter des pauses dans le script (utile pour éviter des erreurs dues à des actions trop rapides)
import time

# Permet de travailler avec des DataFrames (utile pour structurer les données collectées)
import pandas as pd

# %% [markdown]
# Si vous utilisez une version moderne de Selenium et que chromedriver est correctement installé et accessible via le PATH ou dans le même répertoire que votre script, la variable path_chomedriver n'est pas nécessaire.

# %%
# Définition du chemin vers le fichier ChromeDriver qui est nécessaire pour utiliser Selenium avec Chrome
path_chomedriver =  "/home/marwane/mlops-projects/morocco-appartements-price/chromedriver_linux64/chromedriver"
#driver = webdriver.Chrome(executable_path=path_chomedriver, options=options)
#
# Création d'une instance de ChromeOptions pour personnaliser les options du navigateur
options = webdriver.ChromeOptions()

# Ajout d'une option pour exclure les messages de logging de Chrome
options.add_experimental_option('excludeSwitches', ['enable-logging'])

# Initialisation du driver Chrome avec les options définies
driver = webdriver.Chrome(options=options)

# si vous ajouter le "executable_path" dans le cas au vous utilisez un ancie version
driver = webdriver.Chrome(executable_path=path_chomedriver, options=options)

# Le lien du site ascraper
#lien = "https://www.mubawab.ma/fr/ct/casablanca/immobilier-a-vendre:p:2"

# Ouverture du lien spécifiée dans la variable 'lien'
#driver.get(lien)

# Pause de 10 secondes
time.sleep(10)

# Ferme la session du navigateur et ferme la page ouverte
#driver.quit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 15
#      12 driver = webdriver.Chrome(options=options)
#      14 # si vous ajouter le "executable_path" dans le cas au vous utilisez un ancie version
# ---> 15 driver = webdriver.Chrome(executable_path=path_chomedriver, options=options)
#      17 # Le lien du site ascraper
#      18 #lien = "https://www.mubawab.ma/fr/ct/casablanca/immobilier-a-vendre:p:2"
#      19
#    (...)
#      22
#      23 # Pause de 10 secondes
#      24 time.sleep(10)
#
# TypeError: WebDriver.__init__() got an unexpected keyword argument 'executable_path'

# %%
driver.find_element(By.CLASS_NAME, "listingTit").get_attribute("href")

# %% [markdown]
# # links of all pages

# %%
url_pages = []
number_pages = 208
for i in range(1, number_pages + 1):
    url = f"https://www.mubawab.ma/fr/ct/casablanca/immobilier-a-vendre:p:{i}"
    url_pages.append(url)

# %%
len(url_pages)
# Out:
# 208

# %%
url_page = url_pages[0]
url_page

driver = webdriver.Chrome(options=options)
driver.get(url_page)

# %%
# Récupère tous les éléments ayant la classe 'contentBox'
appartements = driver.find_elements(By.CLASS_NAME, "contentBox")

list_liens = []
shared_date = []
# Parcourt chaque élément trouvé
for appartement in appartements:
    try:
        # Trouve le lien (élément <a>) à l'intérieur de l'élément avec la classe 'listingTit'
        lien_element = appartement.find_element(By.CLASS_NAME, "listingTit").find_element(By.TAG_NAME, "a")
        date = appartement.find_element(By.CLASS_NAME, "listingDetails").text
        # Si le lien est trouvé, récupère l'attribut href
        if lien_element is not None:
            lien = lien_element.get_attribute("href")
            #print(lien)
            list_liens.append(lien)
        if date is not None:
            shared_date.append(date)
    except Exception as e:
        # Si un élément n'est pas trouvé ou qu'il y a une erreur, on l'ignore et passe au suivant
        #print(f"Erreur : {e}")
        continue

# %%
len(shared_date), shared_date
# Out:
# (33,
#  ['Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui',
#   'Publié aujourdhui'])

# %%
url_appartements = []
for i in range(len(url_pages[:2])):
    url_page = url_pages[i]

    driver = webdriver.Chrome(options=options)
    driver.get(url_page)
    time.sleep(5)

    # Récupère tous les éléments ayant la classe 'contentBox'
    appartements = driver.find_elements(By.CLASS_NAME, "contentBox")

    # Parcourt chaque élément trouvé
    for appartement in appartements:
        try:
            # Trouve le lien (élément <a>) à l'intérieur de l'élément avec la classe 'listingTit'
            lien_element = appartement.find_element(By.CLASS_NAME, "listingTit").find_element(By.TAG_NAME, "a")
            
            # Si le lien est trouvé, récupère l'attribut href
            if lien_element is not None:
                lien = lien_element.get_attribute("href")
                #print(lien)
                url_appartements.append(lien)
        except Exception as e:
            # Si un élément n'est pas trouvé ou qu'il y a une erreur, on l'ignore et passe au suivant
            #print(f"Erreur : {e}")
            continue

len(url_appartements), url_appartements
# Out:
# (66,
#  ['https://www.mubawab.ma/fr/pa/7503656/beau-studio-%C3%A0-vendre-riviera',
#   'https://www.mubawab.ma/fr/pa/7877405/magnifique-appartement-%C3%A0-vendre-%C3%A0-californie',
#   'https://www.mubawab.ma/fr/pa/7942198/appartement-%C3%A0-vendre-%C3%A0-sidi-maarouf-surface-totale-116-m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/7941889/appartement-%C3%A0-vendre-%C3%A0-sidi-maarouf-2-belles-chambres',
#   'https://www.mubawab.ma/fr/pa/7857674/bel-appartement-%C3%A0-vendre-%C3%A0-ain-sebaa',
#   'https://www.mubawab.ma/fr/pa/7942195/vente-d-un-bel-appartement-%C3%A0-sidi-maarouf-2-chambres-agr%C3%A9ables',
#   'https://www.mubawab.ma/fr/pa/7681416/studio-neuf-de-30-m%C2%B2-%C3%A0-vendre-%C3%A0-sidi-maarouf',
#   'https://www.mubawab.ma/fr/pa/8032129/vente-d-un-bel-appartement-%C3%A0-californie-superficie-126-m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/8041589/tr%C3%A8s-joli-appartement-%C3%A0-vendre-%C3%A0-californie-casablanca',
#   'https://www.mubawab.ma/fr/pa/7698881/appartement-en-vente-%C3%A0-californie-2-belles-chambres',
#   'https://www.mubawab.ma/fr/pa/7966117/vend-appartement-%C3%A0-bernoussi-2-chambres',
#   'https://www.mubawab.ma/fr/a/7995618/bien-beaux-appartements-de-ht-standing',
#   'https://www.mubawab.ma/fr/pa/7941898/appartement-%C3%A0-l-achat-%C3%A0-sidi-maarouf-surface-de-111-m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/7882026/appartement-%C3%A0-l-achat-%C3%A0-anfa-superficie-169-m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/7623672/appartement-97m%C2%B2-en-vente-r%C3%A9sidence-al-badr',
#   'https://www.mubawab.ma/fr/pa/7966959/appartement-%C3%A0-vendre-%C3%A0-lissasfa-surface-totale-99-m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/7926266/appartement-de-37m%C2%B2-et-11m%C2%B2-de-parking',
#   'https://www.mubawab.ma/fr/pa/7941890/vente-d-un-bel-appartement-%C3%A0-sidi-maarouf-superficie-136-m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/7877402/charmant-appartement-%C3%A0-vendre-%C3%A0-californie',
#   'https://www.mubawab.ma/fr/pa/7503652/studio-%C3%A0-vendre-%C3%A0-riviera',
#   'https://www.mubawab.ma/fr/pa/7941879/vente-d-un-bel-appartement-%C3%A0-sidi-maarouf-surface-de-86-m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/7941892/superbe-appartement-%C3%A0-vendre-%C3%A0-sidi-maarouf-superficie-130-m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/7885113/appartement-en-vente-%C3%A0-hay-mohammadi-3-chambres-agr%C3%A9ables',
#   'https://www.mubawab.ma/fr/a/8048412/bel-appartement-%C3%A0-vendre-%C3%A0-tantonville-3-pi%C3%A8ces-confortables-belle-terrasse-et-jardin',
#   'https://www.mubawab.ma/fr/a/8048263/appartement-ensoleill%C3%A9-avec-beau-potentiel-et-terrasse',
#   'https://www.mubawab.ma/fr/a/8046314/appartement-%C3%A0-zahar-oumfa-%C3%A0-vendre',
#   'https://www.mubawab.ma/fr/a/8045791/bel-appartement-%C3%A0-vendre-%C3%A0-belv%C3%A9d%C3%A8re',
#   'https://www.mubawab.ma/fr/a/8043593/vente-d-un-bel-appartement-%C3%A0-sidi-el-khadir-surface-totale-160-m%C2%B2-salon-marocain-et-antenne-parabolique',
#   'https://www.mubawab.ma/fr/a/8043108/bel-appartement-%C3%A0-vendre-%C3%A0-ma%C3%A2rif-extension-surface-totale-101-m%C2%B2-concierge-et-climatisation',
#   'https://www.mubawab.ma/fr/a/8042718/appartement-en-vente-%C3%A0-belv%C3%A9d%C3%A8re-3-belles-chambres-conciergerie-%C3%A0-disposition',
#   'https://www.mubawab.ma/fr/a/8042633/appartement-%C3%A0-l-achat-%C3%A0-beaus%C3%A9jour-3-pi%C3%A8ces-concierge',
#   'https://www.mubawab.ma/fr/a/8042251/excellent-appartement-dans-une-r%C3%A9sidence-s%C3%A9curis%C3%A9e',
#   'https://www.mubawab.ma/fr/a/8041942/appartement-de-162m%C2%B2-quartier-des-hopitaux',
#   'https://www.mubawab.ma/fr/pa/8026993/appartement-a-vendre-a-l-hermitage-avec-1-belle-chambre',
#   'https://www.mubawab.ma/fr/pa/7885305/tr%C3%A8s-bel-appartement-%C3%A0-vendre-%C3%A0-ain-sebaa',
#   'https://www.mubawab.ma/fr/pa/7873365/bel-appartement-%C3%A0-vendre-%C3%A0-oasis-3-chambres-agr%C3%A9ables',
#   'https://www.mubawab.ma/fr/pa/8028091/superbe-appartement-%C3%A0-vendre-%C3%A0-alsace-lorraine-1-belle-chambre',
#   'https://www.mubawab.ma/fr/pa/7941891/bel-appartement-%C3%A0-vendre-%C3%A0-sidi-maarouf-surface-totale-130-m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/7877400/tr%C3%A8s-bel-appartement-%C3%A0-vendre-%C3%A0-californie',
#   'https://www.mubawab.ma/fr/pa/7941883/vente-d-un-bel-appartement-%C3%A0-sidi-maarouf-1-chambre',
#   'https://www.mubawab.ma/fr/pa/7941887/bel-appartement-%C3%A0-vendre-%C3%A0-sidi-maarouf-surface-totale-138-m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/7941895/vend-appartement-%C3%A0-sidi-maarouf-2-chambres-agr%C3%A9ables',
#   'https://www.mubawab.ma/fr/pa/7890174/bel-appartement-%C3%A0-vendre-%C3%A0-lissasfa-superficie-54-m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/8032137/appartement-avec-une-terrasse-d-une-superficie-de-102m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/7941882/vente-d-un-bel-appartement-%C3%A0-sidi-maarouf-1-chambre',
#   'https://www.mubawab.ma/fr/pa/7926268/appartement-de-47m%C2%B2-et11m%C2%B2-de-parking',
#   'https://www.mubawab.ma/fr/pa/7941897/appartement-%C3%A0-vendre-%C3%A0-sidi-maarouf-2-chambres-agr%C3%A9ables',
#   'https://www.mubawab.ma/fr/a/8014312/duplex-%C3%A0-vendre-a-racine',
#   'https://www.mubawab.ma/fr/pa/8041583/tr%C3%A8s-bel-appartement-%C3%A0-vendre-%C3%A0-californie-casablanca',
#   'https://www.mubawab.ma/fr/pa/7966119/appartement-en-vente-%C3%A0-bernoussi-surface-totale-70-m%C2%B2',
#   'https://www.mubawab.ma/fr/pa/7941888/vend-appartement-%C3%A0-sidi-maarouf-2-belles-chambres',
#   'https://www.mubawab.ma/fr/a/7972234/bel-appartement-de-250-m%C2%B2-%C3%A0-la-vente',
#   'https://www.mubawab.ma/fr/a/7591357/appartement-haut-standing-vue-sur-mosqu%C3%A9e-hassan2',
#   'https://www.mubawab.ma/fr/a/7767424/apt-haut-standing-3-chambres-%C3%A0-2min-de-lyautey',
#   'https://www.mubawab.ma/fr/a/8029016/studio-%C3%A0-vendre-%C3%A0-maatif-extension',
#   'https://www.mubawab.ma/fr/a/7851138/appartement-%C3%A0-vendre-2-chambres-%C3%A0-beaus%C3%A9jour',
#   'https://www.mubawab.ma/fr/a/8040898/appartement-%C3%A0-vendre-casablanca-mandarona',
#   'https://www.mubawab.ma/fr/a/8040784/appartement-%C3%A0-vendre-roches-noire',
#   'https://www.mubawab.ma/fr/a/8040001/appartement-a-vendre-131m%C2%B2q-les-princesses-maarif',
#   'https://www.mubawab.ma/fr/a/8039883/appartements-%C3%A0-ain-sebaa',
#   'https://www.mubawab.ma/fr/a/8038378/appartement-hs-%C3%A0-casablanca-les-princesses',
#   'https://www.mubawab.ma/fr/a/8037591/bel-appartement-sur-boulevard-anfa-aupr%C3%A8s-de-l%E2%80%99institut-americaine',
#   'https://www.mubawab.ma/fr/a/8033484/appartement-%C3%A0-vendre-128m%C2%B2-maarif-extension-casablanca',
#   'https://www.mubawab.ma/fr/a/8028675/appartement-%C3%A0-vendre-220-m2',
#   'https://www.mubawab.ma/fr/a/8004639/dernier-etage-3ch-terrasse',
#   'https://www.mubawab.ma/fr/a/7996701/joli-appartement-%C3%A0-casaparc-sidi-maarouf'])

# %% [markdown]
# # All code

# %% [markdown]
# ## Function that retrieve link of all appartment based on given number of pages

# %%
def scrape_link(start_page, end_page):
    """ 
    Methode to scrape the link and shared date of real state
    """
    url_pages = [] 
    for i in range(start_page, end_page + 1):
        url = f"https://www.mubawab.ma/fr/ct/casablanca/immobilier-a-vendre:p:{i}"
        url_pages.append(url)

    shared_date = []
    list_urls = []
    for i in range(len(url_pages)):
        url_page = url_pages[i]

        driver = webdriver.Chrome(options=options)
        driver.get(url_page)
        time.sleep(1)

        # Récupère tous les éléments ayant la classe 'contentBox'
        appartements = driver.find_elements(By.CLASS_NAME, "contentBox")

        # Parcourt chaque élément trouvé
        for appartement in appartements:
            try:
                # Trouve le lien (élément <a>) à l'intérieur de l'élément avec la classe 'listingTit'
                lien_element = appartement.find_element(By.CLASS_NAME, "listingTit").find_element(By.TAG_NAME, "a")
                date = appartement.find_element(By.CLASS_NAME, "listingDetails").text
                
                # Si le lien est trouvé, récupère l'attribut href
                if lien_element is not None:
                    lien = lien_element.get_attribute("href")
                    #print(lien)
                    list_urls.append(lien)

                if date is not None:
                    shared_date.append(date)

            except Exception as e:
                # Si un élément n'est pas trouvé ou qu'il y a une erreur, on l'ignore et passe au suivant
                #print(f"Erreur : {e}")
                continue

        df = pd.DataFrame()
        df["shared_date"] = shared_date
        df["link"] = list_urls
        df.to_csv(f"link-file.csv", index=False)

    return df

# %%
## total pages 208
df_link = scrape_link(start_page = 1, end_page= 208, file_num=1)

# %%
## total pages 208
#df_link = scrape_link(start_page = 1, end_page= 104, file_num=1)
df_link = pd.read_csv("link-file.csv")
df_link.head(5)
# Out:
#          shared_date                                               link
# 0  Publié aujourdhui  https://www.mubawab.ma/fr/a/7987985/studio-pre...
# 1  Publié aujourdhui  https://www.mubawab.ma/fr/a/7987999/studio-pre...
# 2  Publié aujourdhui  https://www.mubawab.ma/fr/a/7858324/studio-pre...
# 3  Publié aujourdhui  https://www.mubawab.ma/fr/pa/7941881/apparteme...
# 4  Publié aujourdhui  https://www.mubawab.ma/fr/pa/7885304/charmant-...

# %% [markdown]
# #### ------------------------------------- END OF LINKS --------------------------------------------

# %%
appartements_infos = []

for i in range(len(url_appartements[0:50])):

    driver = webdriver.Chrome(options=options)
    driver.get(url_appartements[i])
    time.sleep(5) 


    appartement_features = driver.find_element(By.CLASS_NAME, "mainInfoProp")#[0].text
 
    try:
        price = appartement_features.find_element(By.CLASS_NAME, "orangeTit").text
    except:
        price = None
    try:
        surface = appartement_features.find_elements(By.CLASS_NAME, "adDetailFeature")[0].text
    except:
        surface = None
    try:
        piece = appartement_features.find_elements(By.CLASS_NAME, "adDetailFeature")[1].text
    except:
        piece = None
    try:
        rooms = appartement_features.find_elements(By.CLASS_NAME, "adDetailFeature")[2].text
    except:
        rooms = None
    try:
        bathroom = appartement_features.find_elements(By.CLASS_NAME, "adDetailFeature")[3].text
    except:
        bathroom = None
    try:
        address = appartement_features.find_element(By.CLASS_NAME, "greyTit").text
    except:
        address = None

    try:
        appartement_more_infos = driver.find_element(By.CLASS_NAME, "blockProp")

        more_infos = appartement_more_infos.find_element(By.CLASS_NAME, "searchTitle").text
        descriptions = appartement_more_infos.find_elements(By.TAG_NAME, "p")
        description = ["".join(descrip.text) for descrip in descriptions]
        description = "".join(description)
    except:
        description = None

    try:
        more_features = driver.find_element(By.CLASS_NAME, "caractBlockProp")
    except:
        more_infos = None

    try:
        list_features1 = more_features.find_elements(By.CLASS_NAME, "adMainFeature")
    except:
        list_features1= None
    try:
        list_values1 = more_features.find_elements(By.CLASS_NAME, "adMainFeature")
    except:
        list_values1 = None
    try:
        feat_infos_dic1 = {}
        for i in range(len(list_features1)): 
            feat_infos_dic1[f"{list_features1[i].text}"] = f"{list_features1[i].text}"
    except:
        feat_infos_dic1 = None
    
    more_features = driver.find_element(By.CLASS_NAME, "caractBlockProp")
    list_features2 = more_features.find_elements(By.CLASS_NAME, "adFeature")
    #list_values2 = more_features.find_elements(By.CLASS_NAME, "adFeature")
     
    try:
        feat_infos_dic2 = {}
        for i in range(len(list_features2)): 
            feat_infos_dic2[f"{list_features2[i].text}"] = list_features2[i].text
    except:
        feat_infos_dic2 = None
    values = [price, surface, piece, rooms, bathroom, address, more_infos, description, feat_infos_dic1, feat_infos_dic2]
    appartements_infos.append(values)

features = ["price", "surface", "piece", "rooms", "bathroom", "address", "more_infos", "description", "feat_infos_dic1", "feat_infos_dic2"]
df = pd.DataFrame(data=appartements_infos, columns=features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 appartements_infos = []
# ----> 3 for i in range(len(url_appartements[0:50])):
#       5     driver = webdriver.Chrome(options=options)
#       6     driver.get(url_appartements[i])
#
# NameError: name 'url_appartements' is not defined

# %%
df.to_csv("moroccan-appartment-price.csv", index=False)

# %%
# Création d'une instance de ChromeOptions pour personnaliser les options du navigateur
options = webdriver.ChromeOptions()

# Ajout d'une option pour exclure les messages de logging de Chrome
options.add_experimental_option('excludeSwitches', ['enable-logging'])

# Initialisation du driver Chrome avec les options définies
#driver = webdriver.Chrome(options=options)

def scrape_link(number_pages):
    url_pages = [] 
    for i in range(1, number_pages + 1):
        url = f"https://www.mubawab.ma/fr/st/casablanca/appartements-a-vendre:p:{i}"
        url_pages.append(url)


    url_appartements = []
    for i in range(len(url_pages)):
        url_page = url_pages[i]

        driver = webdriver.Chrome(options=options)
        driver.get(url_page)
        time.sleep(5)

        # Récupère tous les éléments ayant la classe 'contentBox'
        appartements = driver.find_elements(By.CLASS_NAME, "contentBox")

        # Parcourt chaque élément trouvé
        for appartement in appartements:
            try:
                # Trouve le lien (élément <a>) à l'intérieur de l'élément avec la classe 'listingTit'
                lien_element = appartement.find_element(By.CLASS_NAME, "listingTit").find_element(By.TAG_NAME, "a")
                
                # Si le lien est trouvé, récupère l'attribut href
                if lien_element is not None:
                    lien = lien_element.get_attribute("href")
                    #print(lien)
                    url_appartements.append(lien)
            except Exception as e:
                # Si un élément n'est pas trouvé ou qu'il y a une erreur, on l'ignore et passe au suivant
                #print(f"Erreur : {e}")
                continue

    return url_appartements

# %%
options = webdriver.ChromeOptions()

# Ajout d'une option pour exclure les messages de logging de Chrome
options.add_experimental_option('excludeSwitches', ['enable-logging'])

# Initialisation du driver Chrome avec les options définies
driver = webdriver.Chrome(options=options)
driver.get("https://www.mubawab.ma/fr/st/casablanca/appartements-a-vendre:p:26")
date_shares = driver.find_elements(By.CLASS_NAME, "listingDetails") #class="listingDetails iconPadR"

# %%
dates = []
for date_share in date_shares:
    date = date_share.text
    dates.append(date)
    
dates
# Out:
# ['Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 1 jour',
#  'Publié il y a 2 jours',
#  'Publié il y a 2 jours',
#  'Publié il y a 2 jours']

# %%
# Création d'une instance de ChromeOptions pour personnaliser les options du navigateur
options = webdriver.ChromeOptions()

# Ajout d'une option pour exclure les messages de logging de Chrome
options.add_experimental_option('excludeSwitches', ['enable-logging'])

# Initialisation du driver Chrome avec les options définies
#driver = webdriver.Chrome(options=options)

def scrape_link(number_pages):
    
    url_pages = [] 
    for i in range(1, number_pages + 1):
        url = f"https://www.mubawab.ma/fr/st/casablanca/appartements-a-vendre:p:{i}"
        url_pages.append(url)

    dates = []
    url_appartements = []
    for i in range(len(url_pages)):
        url_page = url_pages[i]

        driver = webdriver.Chrome(options=options)
        driver.get(url_page)
        time.sleep(5)

        # Récupère tous les éléments ayant la classe 'contentBox'
        #appartements = driver.find_elements(By.CLASS_NAME, "contentBox")
        lien_elements = driver.find_elements(By.CLASS_NAME, "listingTit")#.find_element(By.TAG_NAME, "a")
        date_shares = driver.find_elements(By.CLASS_NAME, "listingDetails")
        # Parcourt chaque élément trouvé

        for date_share in date_shares:
            date = date_share.find_element(By.CLASS_NAME, "listingDetails").text
            dates.append(date)

        for element in lien_elements:
            try:
                # Trouve le lien (élément <a>) à l'intérieur de l'élément avec la classe 'listingTit'
                #lien_element = appartement.find_element(By.CLASS_NAME, "listingTit")
                element_link = element.find_element(By.TAG_NAME, "a")

                # Si le lien est trouvé, récupère l'attribut href
                if element_link is not None:
                    lien = element_link.get_attribute("href")
                    #print(lien)
                    url_appartements.append(lien)
                  

            except Exception as e:
                # Si un élément n'est pas trouvé ou qu'il y a une erreur, on l'ignore et passe au suivant
                #print(f"Erreur : {e}")
                continue

    return url_appartements, dates

url_appartements, dates = scrape_link(number_page=1)
df_link = pd.DataFrame(data=url_appartements, columns=["link"])
df_link.to_csv("casablanca-appartements-links-1.csv", index=False)

len(url_appartements)
# Out:
# '\nurl_appartements, dates = scrape_link(number_page=1)\ndf_link = pd.DataFrame(data=url_appartements, columns=["link"])\ndf_link.to_csv("casablanca-appartements-links-1.csv", index=False)\n\nlen(url_appartements)'

# %%
 
url_appartements, dates = scrape_link(start_page=1, end_page=500)
df_link = pd.DataFrame(data=url_appartements, columns=["link"])
df_link.to_csv("casablanca-appartements-links-1.csv", index=False)

len(url_appartements)

# %%
len(url_appartements)
# Out:
# 1320

# %% [markdown]
# ## ========= Scrape the informations=====

# %%
# Permet d'utiliser le WebDriver pour contrôler un navigateur web
from selenium import webdriver

# Permet de localiser des éléments sur la page web
from selenium.webdriver.common.by import By

# Permet d'ajouter des pauses dans le script (utile pour éviter des erreurs dues à des actions trop rapides)
import time

# Permet de travailler avec des DataFrames (utile pour structurer les données collectées)
import pandas as pd  


def scrape_information(list_link_appartements):
    """ Methode to scrape data from given list of links"""
    options = webdriver.ChromeOptions()

    # Ajout d'une option pour exclure les messages de logging de Chrome
    options.add_experimental_option('excludeSwitches', ['enable-logging'])

    # Initialisation du driver Chrome avec les options définies
    driver = webdriver.Chrome(options=options)
    
    appartements_infos = []
    for i in range(len(list_link_appartements)):
        
        driver = webdriver.Chrome(options=options)
        driver.get(list_link_appartements[i])
        time.sleep(5) 


        try:
            appartement_features = driver.find_element(By.CLASS_NAME, "mainInfoProp")#[0].text
        except:
            appartement_features = None
        try:
            price = appartement_features.find_element(By.CLASS_NAME, "orangeTit").text
        except:
            price = None
        try:
            aire = appartement_features.find_elements(By.CLASS_NAME, "adDetailFeature")[0].text
        except:
            aire = None
        try:
            piece = appartement_features.find_elements(By.CLASS_NAME, "adDetailFeature")[1].text
        except:
            piece = None
        try:
            rooms = appartement_features.find_elements(By.CLASS_NAME, "adDetailFeature")[2].text
        except:
            rooms = None
        try:
            bathroom = appartement_features.find_elements(By.CLASS_NAME, "adDetailFeature")[3].text
        except:
            bathroom = None
        try:
            address = appartement_features.find_element(By.CLASS_NAME, "greyTit").text
        except:
            address = None

        try:
            appartement_more_infos = driver.find_element(By.CLASS_NAME, "blockProp")
        except:
            appartement_more_infos = None
        try:
            more_infos = appartement_more_infos.find_element(By.CLASS_NAME, "searchTitle").text
        except:
            more_infos = None 
        try:    
            descriptions = appartement_more_infos.find_elements(By.TAG_NAME, "p")
            description = ["".join(descrip.text) for descrip in descriptions]
            description = "".join(description)
        except:
            description = None
        try:
            more_features = driver.find_element(By.CLASS_NAME, "caractBlockProp")
        except:
            more_features = None
        try:
            list_features1 = more_features.find_elements(By.CLASS_NAME, "adMainFeature")
        except:
            list_features1=None
        try:
            list_values1 = more_features.find_elements(By.CLASS_NAME, "adMainFeature")
        except:
            list_values1=None
        try:
            feat_infos_dic1 = {}
            for i in range(len(list_features1)): 
                feat_infos_dic1[f"{list_features1[i].text}"] = f"{list_features1[i].text}"
        except:
            feat_infos_dic1 = None
        
        more_features = driver.find_element(By.CLASS_NAME, "caractBlockProp")
        list_features2 = more_features.find_elements(By.CLASS_NAME, "adFeature")
        #list_values2 = more_features.find_elements(By.CLASS_NAME, "adFeature")
        
        try:
            feat_infos_dic2 = {}
            for i in range(len(list_features2)): 
                feat_infos_dic2[f"{list_features2[i].text}"] = list_features2[i].text
        except:
            feat_infos_dic2 = None
        values = [price, aire, piece, rooms, bathroom, address, more_infos, description, feat_infos_dic1, feat_infos_dic2]
        appartements_infos.append(values)


    features = ["price", "aire", "piece", "rooms", "bathroom", "address", "more_infos", "description", "feat_infos_dic1", "feat_infos_dic2"]
    df = pd.DataFrame(data=appartements_infos, columns=features)
    return df

# %%
df_link = pd.read_csv("link-file.csv")
immobier_links = df_link.link.values.tolist() 
len(immobier_links)
# Out:
# 6821

# %%
https://www.mubawab.ma/fr/ct/casablanca/immobilier-a-vendre-all

# %%
data_100 = scrape_information(list_link_appartements=immobier_links[:100])
#data_100.to_csv()

# %%
data_200 = scrape_information(list_link_appartements=immobier_links[:200])
data_200.to_csv("casablanca-immobiliers-0-200.csv", index=False)

# %%
data
# Out:
#           price    aire     piece       rooms           bathroom  \
# 0  1 095 000 DH   45 m²  2 Pièces   1 Chambre    1 Salle de bain
# 1    850 000 DH   42 m²   1 Pièce   1 Chambre    1 Salle de bain
# 2  1 090 000 DH   48 m²   1 Pièce   1 Chambre  2 Salles de bains
# 3  1 175 000 DH   87 m²  2 Pièces   1 Chambre    1 Salle de bain
# 4  1 175 640 DH   96 m²  4 Pièces  3 Chambres  2 Salles de bains
# 5      7 000 DH  105 m²  4 Pièces  3 Chambres  2 Salles de bains
# 6  8 500 000 DH  502 m²  5 Pièces  4 Chambres  3 Salles de bains
# 7  1 872 600 DH  104 m²  4 Pièces  3 Chambres               None
# 8  1 095 000 DH   52 m²   1 Pièce   1 Chambre    1 Salle de bain
# 9  1 020 000 DH   49 m²   1 Pièce   1 Chambre    1 Salle de bain
#
#                            address  \
# 0      Les princesses à Casablanca
# 1               Oasis à Casablanca
# 2             Palmier à Casablanca
# 3        Sidi Maarouf à Casablanca
# 4           Aïn Sebaâ à Casablanca
# 5           Bernoussi à Casablanca
# 6  Ain Diab Extension à Casablanca
# 7          Californie à Casablanca
# 8        Les Hôpitaux à Casablanca
# 9             Riviera à Casablanca
#
#                                           more_infos  \
# 0                            Studio premium à saisir
# 1                            Studio premium à saisir
# 2                            Studio premium à saisir
# 3  Appartement à vendre à Sidi Maarouf. 1 belle c...
# 4          Charmant appartement à vendre à Ain Sebaa
# 5  Vend appartement à Bernoussi. Surface totale 1...
# 6  Villa de luxe à vendre à Ain Diab Extension. S...
# 7       Magnifique appartement à vendre à Californie
# 8                            Studio premium à saisir
# 9                            Studio premium à saisir
#
#                                          description  \
# 0  optez pour des appartements contemporains sur ...
# 1  optez pour des appartements contemporains sur ...
# 2  Magnifique studio de luxe entièrement équipé a...
# 3  Affaire à saisir pour cet appartement à vendre...
# 4  Charmant appartement de 71 m² composé de 2 cha...
# 5  Opportunité unique pour cet appartement à vend...
# 6  Au coeur de Ain Diab Extension, très belle vil...
# 7  Les Allées de Californie 2, plus qu’une simple...
# 8  optez pour des studios contemporains sur quart...
# 9  magnifique studio de luxe entièrement équipée ...
#
#                                      feat_infos_dic1  \
# 0  {'Type de bien
# Appartement': 'Type de bien
# App...
# 1  {'Type de bien
# Appartement': 'Type de bien
# App...
# 2  {'Type de bien
# Appartement': 'Type de bien
# App...
# 3  {'Type de bien
# Appartement': 'Type de bien
# App...
# 4  {'Type de bien
# Appartement': 'Type de bien
# App...
# 5  {'Type de bien
# Appartement': 'Type de bien
# App...
# 6  {'Type de bien
# Villa': 'Type de bien
# Villa', '...
# 7  {'Type de bien
# Appartement': 'Type de bien
# App...
# 8  {'Type de bien
# Appartement': 'Type de bien
# App...
# 9  {'Type de bien
# Appartement': 'Type de bien
# App...
#
#                                      feat_infos_dic2
# 0  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 1  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 2  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 3                         {'Ascenseur': 'Ascenseur'}
# 4  {'Ascenseur': 'Ascenseur', 'Sécurité': 'Sécuri...
# 5                                                 {}
# 6  {'Jardin': 'Jardin', 'Garage': 'Garage', 'Vue ...
# 7  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 8  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 9  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...

# %% [markdown]
# ### ==================

# %%
# Création d'une instance de ChromeOptions pour personnaliser les options du navigateur
options = webdriver.ChromeOptions()

# Ajout d'une option pour exclure les messages de logging de Chrome
options.add_experimental_option('excludeSwitches', ['enable-logging'])

# Initialisation du driver Chrome avec les options définies
#driver = webdriver.Chrome(options=options)

def scrape_link(number_pages):
    
    url_pages = [] 
    for i in range(1, number_pages + 1):
        #url = f"https://www.mubawab.ma/fr/st/casablanca/appartements-a-vendre:p:{i}"
        url = f"https://www.mubawab.ma/fr/ct/casablanca/immobilier-a-vendre-all:p:{i}"
        url_pages.append(url)

    dates = []
    url_appartements = []
    for i in range(len(url_pages)):
        url_page = url_pages[i]

        driver = webdriver.Chrome(options=options)
        driver.get(url_page)
        time.sleep(5)

        # Récupère tous les éléments ayant la classe 'contentBox'
        #appartements = driver.find_elements(By.CLASS_NAME, "contentBox")
        lien_elements = driver.find_elements(By.CLASS_NAME, "listingTit")#.find_element(By.TAG_NAME, "a")
        date_shares = driver.find_elements(By.CLASS_NAME, "listingDetails")
        # Parcourt chaque élément trouvé

        for date_share in date_shares:
            date = date_share.find_element(By.CLASS_NAME, "listingDetails").text
            dates.append(date)

        for element in lien_elements:
            try:
                # Trouve le lien (élément <a>) à l'intérieur de l'élément avec la classe 'listingTit'
                #lien_element = appartement.find_element(By.CLASS_NAME, "listingTit")
                element_link = element.find_element(By.TAG_NAME, "a")

                # Si le lien est trouvé, récupère l'attribut href
                if element_link is not None:
                    lien = element_link.get_attribute("href")
                    #print(lien)
                    url_appartements.append(lien)
                  

            except Exception as e:
                # Si un élément n'est pas trouvé ou qu'il y a une erreur, on l'ignore et passe au suivant
                #print(f"Erreur : {e}")
                continue

    return url_appartements, dates

url_appartements, dates = scrape_link(number_pages=1)
df_link = pd.DataFrame(data=url_appartements, columns=["link"])
df_link.to_csv("casablanca-appartements-links-1.csv", index=False)

len(url_appartements), url_appartements
# Out:
# 'url_appartements, dates = scrape_link(number_pages=1)\ndf_link = pd.DataFrame(data=url_appartements, columns=["link"])\ndf_link.to_csv("casablanca-appartements-links-1.csv", index=False)\n\nlen(url_appartements), url_appartements'

# %%
# Permet d'utiliser le WebDriver pour contrôler un navigateur web
from selenium import webdriver

 # Permet de gérer le service ChromeDriver (non utilisé ici, mais peut être nécessaire dans certains cas)
from selenium.webdriver.chrome.service import Service 
# Permet d'interagir avec le système d'exploitation, par exemple pour gérer les chemins de fichiers
import os
# Permet de localiser des éléments sur la page web
from selenium.webdriver.common.by import By
# Permet d'ajouter des pauses dans le script (utile pour éviter des erreurs dues à des actions trop rapides)
import time

# Permet de travailler avec des DataFrames (utile pour structurer les données collectées)
import pandas as pd 


options = webdriver.ChromeOptions()

# Ajout d'une option pour exclure les messages de logging de Chrome
options.add_experimental_option('excludeSwitches', ['enable-logging'])

# Initialisation du driver Chrome avec les options définies
#driver = webdriver.Chrome(options=options)

path_chomedriver = "/home/marwane/mlops-projects/morocco-appartements-price/chromedriver_linux64/chromedriver"
driver = webdriver.Chrome(options=options)# executable_path=path_chomedriver,

# %%
def scrape_link(start_page, end_page):
    """ 
    Methode to scrape the link and shared date of real state
    """
    url_pages = [] 
    for i in range(start_page, end_page + 1):
        url = f"https://www.mubawab.ma/fr/ct/casablanca/immobilier-a-vendre-all:p:{i}"
        url_pages.append(url)

    shared_date = []
    list_urls = []
    for i in range(len(url_pages)):
        url_page = url_pages[i]

        driver = webdriver.Chrome(options=options)
        driver.get(url_page)
        time.sleep(1)

        # Récupère tous les éléments ayant la classe 'contentBox'
        appartements = driver.find_elements(By.CLASS_NAME, "contentBox")

        # Parcourt chaque élément trouvé
        for appartement in appartements:
            try:
                # Trouve le lien (élément <a>) à l'intérieur de l'élément avec la classe 'listingTit'
                lien_element = appartement.find_element(By.CLASS_NAME, "listingTit").find_element(By.TAG_NAME, "a")
                date = appartement.find_element(By.CLASS_NAME, "listingDetails").text
                
                # Si le lien est trouvé, récupère l'attribut href
                if lien_element is not None:
                    lien = lien_element.get_attribute("href")
                    #print(lien)
                    list_urls.append(lien)

                if date is not None:
                    shared_date.append(date)

            except Exception as e:
                # Si un élément n'est pas trouvé ou qu'il y a une erreur, on l'ignore et passe au suivant
                #print(f"Erreur : {e}")
                continue

        df = pd.DataFrame()
        df["shared_date"] = shared_date
        df["link"] = list_urls
        df.to_csv(f"link-file.csv", index=False)

    return df

# %%
## total pages 208
df_link = scrape_link(start_page = 1, end_page= 263)
# Out:
# There was an error managing chromedriver (error sending request for url (https://chromedriver.storage.googleapis.com/LATEST_RELEASE_114)); using driver found in the cache
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event)

# %%
df_link = pd.read_csv("/home/marwane/mlops-projects/morocco-appartements-price/link-file.csv")
immobier_links = df_link.link.values.tolist()
len(immobier_links)
# Out:
# 8675

# %%
immobier_links[0]
# Out:
# 'https://www.mubawab.ma/fr/pa/7942193/appartement-%C3%A0-vendre-%C3%A0-sidi-maarouf-2-chambres-agr%C3%A9ables'

# %%
url = immobier_links[0]

driver.get(url)

# %%
features = driver.find_element(By.CLASS_NAME, "adDetails")

details_features = features.find_elements(By.CLASS_NAME, "adDetailFeature")

features_dict = {}
for i in range(len(details_features)): 
    features_dict[f"{details_features[i].text}"] = f"{details_features[i].text}"

features_dict
# Out:
# {'45 m²': '45 m²',
#  '2 Pièces': '2 Pièces',
#  '1 Chambre': '1 Chambre',
#  '1 Salle de bain': '1 Salle de bain'}

# %%
address = driver.find_element(By.CLASS_NAME, "greyTit").text
address
# Out:
# 'Les princesses à Casablanca'

# %%
description = driver.find_element(By.CLASS_NAME, "blockProp").text 
description
# Out:
# "Studio premium à saisir\noptez pour des appartements contemporains sur quartier les princesses dotés d'un design d'exception.\n\nMagnifique studio de luxe avec terrasse entièrement équipé avec des finitions modernes et de qualité supérieure,il se compose d'une cuisine moderne américaine,d'un salon spacieux et lumineux avec balcon une grande chambre à coucher avec placards intégrés, une salle de bain avec une douche a l’italienne.\n\nachetez votre appartement dans une résidence premium au coeur de casablanca et profitez d'un rendement locatif de 9% assurés dès l'achat.\n\nNb: une place de parking titrée de 12m2\n\n\nHonoraires d'agence 1%"

# %% [markdown]
# #### Caractéristiques générales

# %%
more_features_1 = driver.find_elements(By.CLASS_NAME, "adMainFeature")

more_features_1_dict = {}
for i in range(len(more_features_1)): 
    more_features_1_dict[f"{more_features_1[i].text}"] = f"{more_features_1[i].text}"

more_features_1_dict
# Out:
# {'Type de bien\nAppartement': 'Type de bien\nAppartement',
#  'Etat\nNouveau': 'Etat\nNouveau',
#  "Etat du bien\nMoins d'un an": "Etat du bien\nMoins d'un an",
#  'Étage du bien\n4ème': 'Étage du bien\n4ème',
#  'Orientation\nSud': 'Orientation\nSud',
#  'Type du sol\nMarbre': 'Type du sol\nMarbre'}

# %%
more_features_2 = driver.find_elements(By.CLASS_NAME, "adFeature")

more_features_2_dict = {}
for i in range(len(more_features_2)): 
    more_features_2_dict[f"{more_features_2[i].text}"] = f"{more_features_2[i].text}"

more_features_2_dict
# Out:
# {'Jardin': 'Jardin',
#  'Terrasse': 'Terrasse',
#  'Garage': 'Garage',
#  'Ascenseur': 'Ascenseur',
#  'Concierge': 'Concierge',
#  'Climatisation': 'Climatisation',
#  'Chauffage central': 'Chauffage central',
#  'Cuisine équipée': 'Cuisine équipée'}

# %%
values = [features_dict, address, description, more_features_1_dict, more_features_2_dict]

values
# Out:
# [{'45 m²': '45 m²',
#   '2 Pièces': '2 Pièces',
#   '1 Chambre': '1 Chambre',
#   '1 Salle de bain': '1 Salle de bain'},
#  'Les princesses à Casablanca',
#  "Studio premium à saisir\noptez pour des appartements contemporains sur quartier les princesses dotés d'un design d'exception.\n\nMagnifique studio de luxe avec terrasse entièrement équipé avec des finitions modernes et de qualité supérieure,il se compose d'une cuisine moderne américaine,d'un salon spacieux et lumineux avec balcon une grande chambre à coucher avec placards intégrés, une salle de bain avec une douche a l’italienne.\n\nachetez votre appartement dans une résidence premium au coeur de casablanca et profitez d'un rendement locatif de 9% assurés dès l'achat.\n\nNb: une place de parking titrée de 12m2\n\n\nHonoraires d'agence 1%",
#  {'Type de bien\nAppartement': 'Type de bien\nAppartement',
#   'Etat\nNouveau': 'Etat\nNouveau',
#   "Etat du bien\nMoins d'un an": "Etat du bien\nMoins d'un an",
#   'Étage du bien\n4ème': 'Étage du bien\n4ème',
#   'Orientation\nSud': 'Orientation\nSud',
#   'Type du sol\nMarbre': 'Type du sol\nMarbre'},
#  {'Jardin': 'Jardin',
#   'Terrasse': 'Terrasse',
#   'Garage': 'Garage',
#   'Ascenseur': 'Ascenseur',
#   'Concierge': 'Concierge',
#   'Climatisation': 'Climatisation',
#   'Chauffage central': 'Chauffage central',
#   'Cuisine équipée': 'Cuisine équipée'}]

# %%
features = ["features_dict", "address", "description", "more_features_1_dict", "more_features_2_dict"]
df = pd.DataFrame(data=[values], columns=features)
df
# Out:
#                                        features_dict  \
# 0  {'45 m²': '45 m²', '2 Pièces': '2 Pièces', '1 ...
#
#                        address  \
# 0  Les princesses à Casablanca
#
#                                          description  \
# 0  Studio premium à saisir\noptez pour des appart...
#
#                                 more_features_1_dict  \
# 0  {'Type de bien
# Appartement': 'Type de bien
# App...
#
#                                 more_features_2_dict
# 0  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...

# %% [markdown]
# ## Define a Methode

# %%
list_informations = []

for i in range(len(immobier_links[:1000])):

    url = immobier_links[i]

    time.sleep(1)

    driver.get(url)

    try:
        features = driver.find_element(By.CLASS_NAME, "adDetails")
    except:
        features = None

    try:
        details_features = features.find_elements(By.CLASS_NAME, "adDetailFeature")

        features_dict = {}
        for i in range(len(details_features)): 
            features_dict[f"{details_features[i].text}"] = f"{details_features[i].text}"
    except:
        details_features = None 

    try:
        address = driver.find_element(By.CLASS_NAME, "greyTit").text
    except:
        address = None

    try:
        description = driver.find_element(By.CLASS_NAME, "blockProp").text 
    except:
        description = None

    try:
        more_features_1 = driver.find_elements(By.CLASS_NAME, "adMainFeature")
        more_features_1_dict = {}
        for i in range(len(more_features_1)): 
            more_features_1_dict[f"{more_features_1[i].text}"] = f"{more_features_1[i].text}"
    except:
        more_features_1 = None

    try:
        more_features_2 = driver.find_elements(By.CLASS_NAME, "adFeature")
        more_features_2_dict = {}
        for i in range(len(more_features_2)): 
            more_features_2_dict[f"{more_features_2[i].text}"] = f"{more_features_2[i].text}"
    except:
        more_features_2 = None

    values = [features_dict, address, description, more_features_1_dict, more_features_2_dict]
    list_informations.append(values)
    
features = ["features_dict", "address", "description", "more_features_1_dict", "more_features_2_dict"]
df = pd.DataFrame(data=list_informations, columns=features)
df
# Out:
#                                          features_dict  \
# 0    {'45 m²': '45 m²', '2 Pièces': '2 Pièces', '1 ...
# 1    {'49 m²': '49 m²', '1 Pièce': '1 Pièce', '1 Ch...
# 2    {'48 m²': '48 m²', '1 Pièce': '1 Pièce', '1 Ch...
# 3    {'87 m²': '87 m²', '2 Pièces': '2 Pièces', '1 ...
# 4    {'96 m²': '96 m²', '4 Pièces': '4 Pièces', '3 ...
# ..                                                 ...
# 995  {'160 m²': '160 m²', '6 Pièces': '6 Pièces', '...
# 996  {'176 m²': '176 m²', '5 Pièces': '5 Pièces', '...
# 997  {'62 m²': '62 m²', '3 Pièces': '3 Pièces', '2 ...
# 998  {'75 m²': '75 m²', '2 Pièces': '2 Pièces', '1 ...
# 999  {'140 m²': '140 m²', '2 Chambres': '2 Chambres...
#
#                                   address  \
# 0             Les princesses à Casablanca
# 1                      Oasis à Casablanca
# 2                    Palmier à Casablanca
# 3               Sidi Maarouf à Casablanca
# 4                  Aïn Sebaâ à Casablanca
# ..                                    ...
# 995                     Anfa à Casablanca
# 996              Mers Sultan à Casablanca
# 997                    Oulfa à Casablanca
# 998  Casablanca Finance City à Casablanca
# 999            Triangle d'Or à Casablanca
#
#                                            description  \
# 0    Studio premium à saisir\noptez pour des appart...
# 1    Studio premium à saisir\noptez pour des appart...
# 2    Studio premium à saisir\nMagnifique studio de ...
# 3    Appartement à vendre à Sidi Maarouf. 1 belle c...
# 4    Charmant appartement à vendre à Ain Sebaa\nCha...
# ..                                                 ...
# 995  CASA Centre coup de fusil 160 m² 4 ch terrasse...
# 996  Un Magnifique Appartement a vendre sur Casabla...
# 997  Bel appartement à vendre à Oulfa. Surface tota...
# 998  4 beaux studios meubles neufs en loc. Cfc\nCAS...
# 999  Appt en vente dernier etage triangle d'or\nTRI...
#
#                                   more_features_1_dict  \
# 0    {'Type de bien
# Appartement': 'Type de bien
# App...
# 1    {'Type de bien
# Appartement': 'Type de bien
# App...
# 2    {'Type de bien
# Appartement': 'Type de bien
# App...
# 3    {'Type de bien
# Appartement': 'Type de bien
# App...
# 4    {'Type de bien
# Appartement': 'Type de bien
# App...
# ..                                                 ...
# 995  {'Type de bien
# Appartement': 'Type de bien
# App...
# 996  {'Type de bien
# Appartement': 'Type de bien
# App...
# 997  {'Type de bien
# Appartement': 'Type de bien
# App...
# 998  {'Type de bien
# Appartement': 'Type de bien
# App...
# 999  {'Type de bien
# Appartement': 'Type de bien
# App...
#
#                                   more_features_2_dict
# 0    {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 1    {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 2    {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 3                           {'Ascenseur': 'Ascenseur'}
# 4    {'Ascenseur': 'Ascenseur', 'Sécurité': 'Sécuri...
# ..                                                 ...
# 995  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 996  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 997  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 998  {'Jardin': 'Jardin', 'Garage': 'Garage', 'Sécu...
# 999  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
#
# [1000 rows x 5 columns]

# %%
#df.to_csv(f"moroccan-houce-price-hhhh1.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.to_csv(f"moroccan-houce-price-hhhh1.csv", index=False)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Fnal code

# %%
# Importation des bibliothèques nécessaires pour le scraping avec Selenium

# Permet de simuler des actions utilisateur (clics, mouvements de souris, etc.)
from selenium.webdriver import ActionChains 

# Permet d'utiliser le WebDriver pour contrôler un navigateur web
from selenium import webdriver

 # Permet de gérer le service ChromeDriver (non utilisé ici, mais peut être nécessaire dans certains cas)
from selenium.webdriver.chrome.service import Service 
# Permet d'interagir avec le système d'exploitation, par exemple pour gérer les chemins de fichiers
import os
# Permet de localiser des éléments sur la page web
from selenium.webdriver.common.by import By
# Permet d'ajouter des pauses dans le script (utile pour éviter des erreurs dues à des actions trop rapides)
import time

# Permet de travailler avec des DataFrames (utile pour structurer les données collectées)
import pandas as pd

# %%
path_chomedriver =  "/home/marwane/mlops-projects/morocco-appartements-price/chromedriver_linux64/chromedriver"
#driver = webdriver.Chrome(executable_path=path_chomedriver, options=options)
#
# Création d'une instance de ChromeOptions pour personnaliser les options du navigateur
options = webdriver.ChromeOptions()

# Ajout d'une option pour exclure les messages de logging de Chrome
options.add_experimental_option('excludeSwitches', ['enable-logging'])
  
# si vous ajouter le "executable_path" dans le cas au vous utilisez un ancie version
#driver = webdriver.Chrome(executable_path=path_chomedriver, options=options)
driver = webdriver.Chrome(options=options)


def scrape_info(start_link,end_link, num_file):
    list_informations = []
    for i in range(len(immobier_links[start_link:end_link])):

        url = immobier_links[i]

        time.sleep(1)

        driver.get(url)

        try:
            features = driver.find_element(By.CLASS_NAME, "adDetails")
        except:
            features = None

        try:
            details_features = features.find_elements(By.CLASS_NAME, "adDetailFeature")

            features_dict = {}
            for i in range(len(details_features)): 
                features_dict[f"{details_features[i].text}"] = f"{details_features[i].text}"
        except:
            details_features = None 

        try:
            address = driver.find_element(By.CLASS_NAME, "greyTit").text
        except:
            address = None

        try:
            description = driver.find_element(By.CLASS_NAME, "blockProp").text 
        except:
            description = None

        try:
            more_features_1 = driver.find_elements(By.CLASS_NAME, "adMainFeature")
            more_features_1_dict = {}
            for i in range(len(more_features_1)): 
                more_features_1_dict[f"{more_features_1[i].text}"] = f"{more_features_1[i].text}"
        except:
            more_features_1 = None

        try:
            more_features_2 = driver.find_elements(By.CLASS_NAME, "adFeature")
            more_features_2_dict = {}
            for i in range(len(more_features_2)): 
                more_features_2_dict[f"{more_features_2[i].text}"] = f"{more_features_2[i].text}"
        except:
            more_features_2 = None

        values = [features_dict, address, description, more_features_1_dict, more_features_2_dict]
        list_informations.append(values)
        
    features = ["features_dict", "address", "description", "more_features_1_dict", "more_features_2_dict"]
    df = pd.DataFrame(data=list_informations, columns=features)
    df.to_csv(f"data/moroccan-houce-price-{num_file}.csv", index=False)
    return df

# %%
scrape_info(start_link=0 ,end_link=1000 , num_file=1)
# Out:
#                                          features_dict  \
# 0    {'112 m²': '112 m²', '3 Pièces': '3 Pièces', '...
# 1    {'60 m²': '60 m²', '1 Salle de bain': '1 Salle...
# 2    {'71 m²': '71 m²', '3 Pièces': '3 Pièces', '2 ...
# 3    {'2500 m²': '2500 m²', '7 Pièces': '7 Pièces',...
# 4    {'176 m²': '176 m²', '5 Pièces': '5 Pièces', '...
# ..                                                 ...
# 995  {'30 m²': '30 m²', '1 Salle de bain': '1 Salle...
# 996  {'126 m²': '126 m²', '3 Pièces': '3 Pièces', '...
# 997  {'91 m²': '91 m²', '4 Pièces': '4 Pièces', '3 ...
# 998  {'209 m²': '209 m²', '4 Pièces': '4 Pièces', '...
# 999  {'1120 m²': '1120 m²', '6 Pièces': '6 Pièces',...
#
#                          address  \
# 0      Sidi Maarouf à Casablanca
# 1       Hay Hassani à Casablanca
# 2         Aïn Sebaâ à Casablanca
# 3    Anfa Supérieur à Casablanca
# 4       Mers Sultan à Casablanca
# ..                           ...
# 995       Derb Omar à Casablanca
# 996      Californie à Casablanca
# 997       Aïn Sebaâ à Casablanca
# 998      Californie à Casablanca
# 999      Californie à Casablanca
#
#                                            description  \
# 0    Appartement à vendre à Sidi Maarouf. 2 chambre...
# 1    Plateau bureau à vendre en plein quartier Hay ...
# 2    Très bel appartement à vendre à Ain Sebaa\nCha...
# 3    Villa à démolir à vendre sur Anfa Supérieur\nV...
# 4    Un Magnifique Appartement a vendre sur Casabla...
# ..                                                 ...
# 995  Local à vendre Surface de 30m² dont 10m² de me...
# 996  Vente d'un bel appartement à Californie. Super...
# 997  Vend appartement à Aïn Sebaâ. 3 chambres\nAche...
# 998  Grand Appartement à Vendre\nSaigh Immo met en ...
# 999  Villa moderne avec piscine à vendre\nSaigh imm...
#
#                                   more_features_1_dict  \
# 0    {'Type de bien
# Appartement': 'Type de bien
# App...
# 1    {'Type de bien
# Bureau': 'Type de bien
# Bureau',...
# 2    {'Type de bien
# Appartement': 'Type de bien
# App...
# 3    {'Type de bien
# Villa': 'Type de bien
# Villa', '...
# 4    {'Type de bien
# Appartement': 'Type de bien
# App...
# ..                                                 ...
# 995  {'Type de bien
# Local commercial': 'Type de bie...
# 996  {'Type de bien
# Appartement': 'Type de bien
# App...
# 997  {'Type de bien
# Appartement': 'Type de bien
# App...
# 998  {'Type de bien
# Appartement': 'Type de bien
# App...
# 999  {'Type de bien
# Villa': 'Type de bien
# Villa', '...
#
#                                   more_features_2_dict
# 0                                                   {}
# 1                                                   {}
# 2    {'Ascenseur': 'Ascenseur', 'Sécurité': 'Sécuri...
# 3    {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 4    {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# ..                                                 ...
# 995                                                 {}
# 996     {'Terrasse': 'Terrasse', 'Piscine': 'Piscine'}
# 997                                                 {}
# 998  {'Jardin': 'Jardin', 'Garage': 'Garage', 'Asce...
# 999  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
#
# [1000 rows x 5 columns]

# %%
time.sleep(400)
df2 = scrape_info(start_link=1000 ,end_link=3000 , num_file=2)

# %%
#time.sleep(600)
df3 = scrape_info(start_link=3000 ,end_link=4000 , num_file=3)

# %%
#df3.head(10)

# %%
#time.sleep(600)
df4 = scrape_info(start_link=4000 ,end_link=5000 , num_file=4)

# %%
df_link = pd.read_csv("/home/marwane/mlops-projects/morocco-appartements-price/link-file.csv")
immobier_links = df_link.link.values.tolist()
len(immobier_links)
# Out:
# 8675

# %%
df_link = pd.read_csv("/home/marwane/mlops-projects/morocco-appartements-price/link-file.csv")
immobier_links = df_link.link.values.tolist()
len(immobier_links)
# Out:
# 8675

# %%
df5 = scrape_info(start_link=5000 ,end_link=6000 , num_file=5)

# %%
time.sleep(600)
df6 = scrape_info(start_link=6000 ,end_link=8675 , num_file=6)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File ~/anaconda3/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File ~/anaconda3/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~/anaconda3/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File ~/anaconda3/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     707 try:
# --> 708     return self._sock.recv_into(b)
#     709 except timeout:
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# Cell In[8], line 2
#       1 time.sleep(600)
# ----> 2 df6 = scrape_info(start_link=6000 ,end_link=8675 , num_file=6)
#
# Cell In[3], line 23, in scrape_info(start_link, end_link, num_file)
#      19 url = immobier_links[i]
#      21 time.sleep(1)
# ---> 23 driver.get(url)
#      25 try:
#      26     features = driver.find_element(By.CLASS_NAME, "adDetails")
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:393, in WebDriver.get(self, url)
#     391 def get(self, url: str) -> None:
#     392     """Loads a web page in the current browser session."""
# --> 393     self.execute(Command.GET, {"url": url})
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:382, in WebDriver.execute(self, driver_command, params)
#     379     elif "sessionId" not in params:
#     380         params["sessionId"] = self.session_id
# --> 382 response = self.command_executor.execute(driver_command, params)
#     383 if response:
#     384     self.error_handler.check_response(response)
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/selenium/webdriver/remote/remote_connection.py:404, in RemoteConnection.execute(self, command, params)
#     402 trimmed = self._trim_large_entries(params)
#     403 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404 return self._request(command_info[0], url, body=data)
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/selenium/webdriver/remote/remote_connection.py:428, in RemoteConnection._request(self, method, url, body)
#     425     body = None
#     427 if self._client_config.keep_alive:
# --> 428     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429     statuscode = response.status
#     430 else:
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)
#     140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840 elif isinstance(new_e, (OSError, HTTPException)):
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#     848 # Keep track of the error for the retry warning.
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     471 elif error and self._is_read_error(error):
#     472     # Read retry?
#     473     if read is False or method is None or not self._is_method_retryable(method):
# --> 474         raise reraise(type(error), error, _stacktrace)
#     475     elif read is not None:
#     476         read -= 1
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      37     if value.__traceback__ is not tb:
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#      41     value = None  # type: ignore[assignment]
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#     541 # Set properties that are used by the pooling layer.
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/connectionpool.py:369, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 """Is the error actually a timeout? Will raise a ReadTimeout or pass"""
#     368 if isinstance(err, SocketTimeout):
# --> 369     raise ReadTimeoutError(
#     370         self, url, f"Read timed out. (read timeout={timeout_value})"
#     371     ) from err
#     373 # See the above comment about EAGAIN in Python 3.
#     374 if hasattr(err, "errno") and err.errno in _blocking_errnos:
#
# ReadTimeoutError: HTTPConnectionPool(host='localhost', port=39231): Read timed out. (read timeout=120)
