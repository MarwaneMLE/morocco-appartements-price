# %%
import pandas as pd  

# Display all columns
pd.set_option("display.max_columns", None) 
# display all rows
pd.set_option("display.max_rows", None)

p = "moroccan-immobilier-houses-price-1.csv"
pd.read_csv(p)
# Out:
#                 price   surface              piece              rooms  \
# 0        1 062 700 DH    112 m²           3 Pièces         2 Chambres
# 1          913 100 DH     60 m²    1 Salle de bain                NaN
# 2          894 400 DH     71 m²           3 Pièces         2 Chambres
# 3       45 000 000 DH   2500 m²           7 Pièces         5 Chambres
# 4        2 500 000 DH    176 m²           5 Pièces         3 Chambres
# 5        1 159 160 DH    119 m²           3 Pièces         2 Chambres
# 6        1 458 000 DH    118 m²           3 Pièces         2 Chambres
# 7        1 212 000 DH     53 m²           2 Pièces          1 Chambre
# 8       10 500 000 DH    557 m²           6 Pièces         5 Chambres
# 9        4 400 000 DH    169 m²           3 Pièces         2 Chambres
# 10       1 695 000 DH    138 m²         2 Chambres    1 Salle de bain
# 11       1 410 000 DH     99 m²           4 Pièces         3 Chambres
# 12       1 100 000 DH     91 m²           4 Pièces         2 Chambres
# 13       1 690 000 DH    147 m²           4 Pièces         3 Chambres
# 14         998 675 DH     65 m²    1 Salle de bain                NaN
# 15       2 550 000 DH     33 m²    1 Salle de bain                NaN
# 16         960 000 DH     87 m²           4 Pièces         3 Chambres
# 17       9 800 000 DH    503 m²           8 Pièces         4 Chambres
# 18       1 590 000 DH    133 m²           4 Pièces         3 Chambres
# 19       1 502 500 DH    111 m²         2 Chambres    1 Salle de bain
# 20       1 458 000 DH    118 m²           3 Pièces         2 Chambres
# 21         700 000 DH     27 m²    1 Salle de bain                NaN
# 22         940 000 DH     70 m²    1 Salle de bain                NaN
# 23       1 196 000 DH    111 m²           3 Pièces         2 Chambres
# 24         460 000 DH     55 m²           3 Pièces         3 Chambres
# 25         350 000 DH     32 m²    1 Salle de bain                NaN
# 26       3 000 000 DH     82 m²    1 Salle de bain                NaN
# 27       6 500 000 DH    389 m²                NaN                NaN
# 28      25 000 000 DH  15000 m²                NaN                NaN
# 29       2 400 000 DH    188 m²    1 Salle de bain                NaN
# 30       1 700 000 DH    145 m²           3 Pièces         2 Chambres
# 31       2 800 000 DH    256 m²           2 Pièces         3 Chambres
# 32       1 600 000 DH    143 m²           3 Pièces          1 Chambre
# 33         720 000 DH     12 m²    1 Salle de bain                NaN
# 34         928 800 DH     86 m²           4 Pièces         3 Chambres
# 35       1 866 700 DH    113 m²           4 Pièces         3 Chambres
# 36         894 400 DH     71 m²           4 Pièces         2 Chambres
# 37         670 000 DH     72 m²           3 Pièces         2 Chambres
# 38       1 829 000 DH    109 m²           4 Pièces         3 Chambres
# 39       1 175 640 DH     96 m²           4 Pièces         3 Chambres
# 40       1 706 230 DH     99 m²           3 Pièces         3 Chambres
# 41       9 200 000 DH    271 m²                NaN                NaN
# 42       3 650 000 DH    238 m²           4 Pièces         3 Chambres
# 43       7 900 000 DH    360 m²           5 Pièces         4 Chambres
# 44       2 250 000 DH    110 m²           4 Pièces         3 Chambres
# 45       2 750 000 DH    160 m²           4 Pièces         3 Chambres
# 46       3 300 000 DH    284 m²           5 Pièces         4 Chambres
# 47       1 175 000 DH     87 m²           2 Pièces          1 Chambre
# 48       1 400 000 DH     91 m²           4 Pièces         3 Chambres
# 49       1 866 700 DH    109 m²           4 Pièces         3 Chambres
# 50       1 810 000 DH    100 m²           4 Pièces         3 Chambres
# 51       6 300 000 DH    360 m²                NaN                NaN
# 52       1 421 000 DH    105 m²           3 Pièces         2 Chambres
# 53         993 000 DH     47 m²           2 Pièces          1 Chambre
# 54       1 023 000 DH    132 m²                NaN                NaN
# 55       1 240 000 DH     62 m²           3 Pièces         2 Chambres
# 56           8 500 DH    410 m²           4 Pièces         4 Chambres
# 57       1 220 000 DH     51 m²            1 Pièce          1 Chambre
# 58       1 300 000 DH    160 m²           8 Pièces         3 Chambres
# 59       2 617 500 DH    349 m²                NaN                NaN
# 60       1 300 000 DH    101 m²           2 Pièces         2 Chambres
# 61       8 500 000 DH    243 m²    1 Salle de bain                NaN
# 62       1 900 000 DH    160 m²           3 Pièces         3 Chambres
# 63       2 100 000 DH    100 m²           8 Pièces         6 Chambres
# 64       1 160 000 DH    103 m²           3 Pièces         2 Chambres
# 65       1 030 000 DH     92 m²           4 Pièces         2 Chambres
# 66       1 695 000 DH    138 m²           3 Pièces         2 Chambres
# 67         887 375 DH     55 m²    1 Salle de bain                NaN
# 68       2 380 000 DH     75 m²    1 Salle de bain                NaN
# 69         190 000 DH     55 m²           3 Pièces         2 Chambres
# 70         825 320 DH     52 m²    1 Salle de bain                NaN
# 71       1 132 750 DH     98 m²           4 Pièces         3 Chambres
# 72       1 062 700 DH    112 m²         2 Chambres    1 Salle de bain
# 73       1 394 500 DH    116 m²         2 Chambres    1 Salle de bain
# 74           7 000 DH     81 m²           4 Pièces         3 Chambres
# 75         250 000 DH     59 m²           3 Pièces         2 Chambres
# 76         250 000 DH     59 m²           3 Pièces         2 Chambres
# 77         250 000 DH     52 m²           3 Pièces         2 Chambres
# 78         250 000 DH     52 m²           3 Pièces         2 Chambres
# 79          18 000 DH    100 m²    1 Salle de bain                NaN
# 80          18 000 DH    100 m²    1 Salle de bain                NaN
# 81          15 000 DH     14 m²    1 Salle de bain                NaN
# 82          15 000 DH     14 m²    1 Salle de bain                NaN
# 83       5 485 000 DH    369 m²           5 Pièces         4 Chambres
# 84       5 892 000 DH    390 m²           5 Pièces         4 Chambres
# 85       5 474 000 DH    329 m²           5 Pièces         4 Chambres
# 86       5 420 000 DH    306 m²           5 Pièces                NaN
# 87       5 720 000 DH    369 m²           5 Pièces         4 Chambres
# 88         816 000 DH     67 m²           3 Pièces         2 Chambres
# 89       1 700 000 DH    162 m²           5 Pièces         3 Chambres
# 90       3 750 000 DH    175 m²            1 Pièce          1 Chambre
# 91       9 250 000 DH    321 m²    1 Salle de bain                NaN
# 92          28 000 DH    349 m²  2 Salles de bains                NaN
# 93       1 900 000 DH    131 m²           4 Pièces         3 Chambres
# 94           9 500 DH    108 m²           2 Pièces         2 Chambres
# 95       1 590 000 DH    109 m²           4 Pièces         3 Chambres
# 96       2 200 000 DH    162 m²           5 Pièces         3 Chambres
# 97       1 500 000 DH    128 m²           7 Pièces         3 Chambres
# 98       6 500 000 DH    202 m²  2 Salles de bains                NaN
# 99       1 120 000 DH    105 m²           4 Pièces         3 Chambres
# 100        250 000 DH     56 m²           3 Pièces         2 Chambres
# 101        250 000 DH     55 m²           3 Pièces         2 Chambres
# 102        250 000 DH     51 m²           3 Pièces         2 Chambres
# 103        250 000 DH     51 m²           3 Pièces         2 Chambres
# 104        250 000 DH     58 m²    1 Salle de bain                NaN
# 105        250 000 DH     58 m²           3 Pièces         2 Chambres
# 106        270 000 DH     18 m²    1 Salle de bain                NaN
# 107      1 128 000 DH    146 m²           3 Pièces         2 Chambres
# 108      2 596 000 DH     59 m²                NaN                NaN
# 109      3 303 300 DH    115 m²                NaN                NaN
# 110        502 320 DH     21 m²    1 Salle de bain                NaN
# 111        499 200 DH     16 m²                NaN                NaN
# 112      1 220 670 DH     81 m²    1 Salle de bain                NaN
# 113      1 663 350 DH    139 m²                NaN                NaN
# 114      1 663 350 DH    139 m²                NaN                NaN
# 115      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 116      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 117      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 118      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 119      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 120      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 121      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 122      3 300 000 DH    220 m²            1 Pièce         3 Chambres
# 123      1 990 000 DH    114 m²           5 Pièces         3 Chambres
# 124      1 150 000 DH     97 m²           4 Pièces         3 Chambres
# 125        940 000 DH     94 m²            1 Pièce         2 Chambres
# 126      1 400 000 DH    256 m²                NaN                NaN
# 127        850 000 DH     75 m²           2 Pièces         2 Chambres
# 128      3 000 000 DH    245 m²    1 Salle de bain                NaN
# 129      1 400 000 DH    217 m²           7 Pièces         4 Chambres
# 130      1 150 000 DH    107 m²           4 Pièces         2 Chambres
# 131     15 176 200 DH    898 m²           5 Pièces         4 Chambres
# 132        270 000 DH     18 m²    1 Salle de bain                NaN
# 133      7 810 000 DH    382 m²           5 Pièces         4 Chambres
# 134      7 810 000 DH    382 m²           5 Pièces         4 Chambres
# 135      7 370 000 DH    377 m²           5 Pièces         4 Chambres
# 136      7 370 000 DH    377 m²           5 Pièces         4 Chambres
# 137      7 200 000 DH    377 m²           5 Pièces         4 Chambres
# 138      7 200 000 DH    377 m²           5 Pièces         4 Chambres
# 139      5 892 000 DH    348 m²           5 Pièces         4 Chambres
# 140      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 141      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 142      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 143      1 000 650 DH     66 m²           3 Pièces         2 Chambres
# 144        883 050 DH     75 m²           3 Pièces         2 Chambres
# 145      1 171 800 DH    104 m²           4 Pièces         3 Chambres
# 146        887 250 DH     70 m²           3 Pièces         2 Chambres
# 147        590 000 DH     37 m²           2 Pièces          1 Chambre
# 148      1 024 600 DH     94 m²           4 Pièces         3 Chambres
# 149        930 000 DH     88 m²           4 Pièces         3 Chambres
# 150      1 600 000 DH    130 m²           4 Pièces         2 Chambres
# 151      1 700 000 DH    159 m²           5 Pièces         3 Chambres
# 152      1 620 000 DH    148 m²           5 Pièces         3 Chambres
# 153      1 460 000 DH    124 m²           5 Pièces         2 Chambres
# 251      8 000 000 DH    436 m²    1 Salle de bain                NaN
# 252      1 090 000 DH     93 m²           4 Pièces         3 Chambres
# 253        502 320 DH     21 m²    1 Salle de bain                NaN
# 254        780 000 DH     63 m²           3 Pièces         2 Chambres
# 255      2 380 000 DH     75 m²    1 Salle de bain                NaN
# 256      1 730 000 DH    105 m²         3 Chambres  2 Salles de bains
# 257        890 000 DH     59 m²    1 Salle de bain                NaN
# 258      1 045 000 DH     55 m²    1 Salle de bain                NaN
# 259      1 450 000 DH    117 m²           3 Pièces         2 Chambres
# 260      1 330 000 DH     97 m²           4 Pièces         3 Chambres
# 261      4 080 000 DH    160 m²           3 Pièces         2 Chambres
# 262      1 280 000 DH     51 m²    1 Salle de bain                NaN
# 263      1 650 000 DH    129 m²           3 Pièces         3 Chambres
# 264        893 885 DH     57 m²    1 Salle de bain                NaN
# 265      1 130 250 DH     75 m²    1 Salle de bain                NaN
# 266      1 003 200 DH     48 m²                NaN                NaN
# 267        964 480 DH     64 m²    1 Salle de bain                NaN
# 268      2 948 000 DH     67 m²                NaN                NaN
# 269      3 718 000 DH    130 m²                NaN                NaN
# 270        509 600 DH     20 m²    1 Salle de bain                NaN
# 271        540 800 DH     17 m²                NaN                NaN
# 272        880 000 DH     30 m²    1 Salle de bain                NaN
# 273        457 600 DH     16 m²    1 Salle de bain                NaN
# 274        700 000 DH     27 m²    1 Salle de bain                NaN
# 275        590 000 DH     37 m²           2 Pièces          1 Chambre
# 276        720 000 DH     79 m²           3 Pièces         2 Chambres
# 277      7 200 000 DH    700 m²    1 Salle de bain                NaN
# 278      2 200 000 DH    118 m²    1 Salle de bain                NaN
# 279        580 000 DH     54 m²           2 Pièces         2 Chambres
# 280      2 300 000 DH     91 m²            1 Pièce         2 Chambres
# 281      3 100 000 DH    145 m²            1 Pièce         3 Chambres
# 282      1 720 000 DH     59 m²            1 Pièce          1 Chambre
# 283      1 950 000 DH     85 m²            1 Pièce          1 Chambre
# 284      1 150 000 DH    105 m²           4 Pièces         3 Chambres
# 285         22 000 DH     18 m²    1 Salle de bain                NaN
# 286      3 900 000 DH    209 m²           5 Pièces         4 Chambres
# 287      1 550 000 DH    111 m²           3 Pièces         2 Chambres
# 288      2 450 000 DH    168 m²           5 Pièces         4 Chambres
# 289      1 083 000 DH     57 m²    1 Salle de bain                NaN
# 290      1 298 000 DH     59 m²    1 Salle de bain                NaN
# 291               NaN    110 m²           3 Pièces         2 Chambres
# 292      9 200 000 DH    374 m²           6 Pièces         4 Chambres
# 293      1 350 000 DH     96 m²           3 Pièces         2 Chambres
# 294      1 210 000 DH     44 m²            1 Pièce         2 Chambres
# 295        806 333 DH     39 m²           2 Pièces          1 Chambre
# 296        935 000 DH     99 m²           4 Pièces         3 Chambres
# 297        994 620 DH     66 m²    1 Salle de bain                NaN
# 298      1 620 100 DH     87 m²           3 Pièces         2 Chambres
# 299      1 503 900 DH     82 m²           3 Pièces         2 Chambres
# 300      1 529 000 DH     81 m²           3 Pièces         2 Chambres
# 301      1 583 700 DH     84 m²           3 Pièces         2 Chambres
# 302      1 475 900 DH     78 m²           3 Pièces         2 Chambres
# 303      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 304      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 305          7 000 DH     65 m²           3 Pièces         2 Chambres
# 306      7 650 000 DH    417 m²           3 Pièces         3 Chambres
# 307        700 000 DH     75 m²           3 Pièces         2 Chambres
# 308      5 000 000 DH    185 m²           4 Pièces         3 Chambres
# 309        735 000 DH     81 m²           3 Pièces         2 Chambres
# 310      2 130 000 DH    133 m²           4 Pièces         3 Chambres
# 311     11 300 000 DH    571 m²           5 Pièces         4 Chambres
# 312        700 000 DH     48 m²           2 Pièces          1 Chambre
# 313      3 350 000 DH    250 m²           5 Pièces         4 Chambres
# 314        920 000 DH     87 m²           4 Pièces         3 Chambres
# 315     10 200 000 DH    460 m²           7 Pièces         4 Chambres
# 316      2 790 000 DH    155 m²           5 Pièces         3 Chambres
# 317      2 300 000 DH    192 m²           5 Pièces         3 Chambres
# 318      7 500 000 DH    475 m²           8 Pièces         6 Chambres
# 319      4 600 000 DH    259 m²           6 Pièces         4 Chambres
# 320        943 000 DH     82 m²           4 Pièces         3 Chambres
# 321      1 320 000 DH    156 m²           5 Pièces         4 Chambres
# 322        700 000 DH     84 m²           3 Pièces         2 Chambres
# 323      1 350 000 DH     53 m²           2 Pièces          1 Chambre
# 324        935 000 DH     99 m²           4 Pièces         3 Chambres
# 325        979 800 DH     46 m²           2 Pièces          1 Chambre
# 326     25 000 000 DH   2527 m²          10 Pièces         5 Chambres
# 327     20 000 000 DH   1500 m²           6 Pièces         4 Chambres
# 328      2 800 000 DH    250 m²           8 Pièces         5 Chambres
# 329      5 287 000 DH    622 m²                NaN                NaN
# 330      1 663 350 DH    139 m²           3 Pièces         3 Chambres
# 331      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 332      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 333      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 334      1 663 350 DH    139 m²           3 Pièces         2 Chambres
# 335      1 663 350 DH    139 m²           4 Pièces         3 Chambres
# 336        898 800 DH     76 m²         2 Chambres    1 Salle de bain
# 337        953 400 DH     77 m²           3 Pièces         2 Chambres
# 338      9 000 000 DH    524 m²           8 Pièces         4 Chambres
# 339      1 800 000 DH    136 m²           5 Pièces         3 Chambres
# 340        580 000 DH     71 m²           3 Pièces         2 Chambres
# 341      1 023 000 DH    132 m²                NaN                NaN
# 342      1 100 000 DH    103 m²           4 Pièces         3 Chambres
# 343      2 300 000 DH    177 m²           5 Pièces         3 Chambres
# 344        950 000 DH     90 m²           3 Pièces         2 Chambres
# 345        875 750 DH    113 m²                NaN                NaN
# 346      4 000 000 DH    159 m²           3 Pièces         3 Chambres
# 347        720 000 DH     63 m²           3 Pièces         2 Chambres
# 348      1 057 300 DH     97 m²           4 Pièces         3 Chambres
# 349     11 300 000 DH    549 m²           5 Pièces         4 Chambres
# 350        190 000 DH     54 m²           3 Pièces         2 Chambres
# 351      1 150 000 DH    105 m²           4 Pièces         3 Chambres
# 352      9 900 000 DH    410 m²           5 Pièces         4 Chambres
# 353      5 142 500 DH    605 m²                NaN                NaN
# 354      5 236 000 DH    616 m²                NaN                NaN
# 355      5 346 500 DH    629 m²                NaN                NaN
# 406        950 000 DH     54 m²    1 Salle de bain                NaN
# 407        875 750 DH    113 m²                NaN                NaN
# 408        928 800 DH     86 m²           4 Pièces         3 Chambres
# 409     10 000 000 DH    650 m²           4 Pièces         4 Chambres
# 410      1 260 000 DH     81 m²    1 Salle de bain                NaN
# 411        820 000 DH     62 m²           3 Pièces         2 Chambres
# 412      4 520 000 DH    231 m²           5 Pièces         4 Chambres
# 413      2 120 000 DH    132 m²           4 Pièces         3 Chambres
# 414        950 000 DH     38 m²    1 Salle de bain                NaN
# 415      1 132 750 DH     98 m²           4 Pièces         3 Chambres
# 416      1 090 000 DH    100 m²           4 Pièces         3 Chambres
# 417      4 700 000 DH    257 m²           4 Pièces         4 Chambres
# 418        950 000 DH    130 m²           6 Pièces         2 Chambres
# 419     15 000 000 DH    230 m²            1 Pièce          1 Chambre
# 420        950 000 DH     73 m²           2 Pièces         2 Chambres
# 421      3 900 000 DH    155 m²    1 Salle de bain                NaN
# 422      1 300 000 DH    130 m²            1 Pièce         3 Chambres
# 423      8 000 000 DH    500 m²           3 Pièces         6 Chambres
# 424      2 950 000 DH    221 m²    1 Salle de bain                NaN
# 425      2 300 000 DH    160 m²           3 Pièces         3 Chambres
# 426               NaN    112 m²         2 Chambres    1 Salle de bain
# 427      8 200 000 DH    508 m²                NaN                NaN
# 428     18 000 000 DH   1235 m²                NaN                NaN
# 429      1 160 000 DH     99 m²           4 Pièces         2 Chambres
# 430      1 440 000 DH    124 m²           5 Pièces         2 Chambres
# 431      1 130 000 DH     89 m²           5 Pièces         2 Chambres
# 432      1 670 000 DH    148 m²           5 Pièces         3 Chambres
# 433      1 490 000 DH    111 m²           5 Pièces         3 Chambres
# 434        510 000 DH     24 m²  2 Salles de bains                NaN
# 435      1 130 000 DH     89 m²           5 Pièces         2 Chambres
# 436      1 420 000 DH    106 m²           4 Pièces         2 Chambres
# 437      1 450 000 DH    121 m²           4 Pièces         3 Chambres
# 438      6 600 000 DH    389 m²                NaN                NaN
# 439      1 110 000 DH     81 m²           3 Pièces         2 Chambres
# 440        950 000 DH     54 m²    1 Salle de bain                NaN
# 441        780 000 DH     90 m²           4 Pièces         3 Chambres
# 442      9 397 500 DH    537 m²                NaN                NaN
# 443      2 793 000 DH    147 m²           4 Pièces         3 Chambres
# 444      3 400 000 DH    220 m²           5 Pièces         4 Chambres
# 445      1 330 000 DH    101 m²           4 Pièces         3 Chambres
# 446        250 000 DH     54 m²           3 Pièces         2 Chambres
# 447        980 000 DH     58 m²    1 Salle de bain                NaN
# 448      7 950 000 DH    443 m²  3 Salles de bains                NaN
# 449          7 000 DH     81 m²           4 Pièces         3 Chambres
# 450      1 110 000 DH     81 m²           3 Pièces         2 Chambres
# 451        845 000 DH     77 m²           4 Pièces         3 Chambres
# 452        670 000 DH     90 m²           2 Pièces         3 Chambres
# 453      4 500 000 DH    250 m²           3 Pièces         4 Chambres
# 454      4 300 000 DH    110 m²            1 Pièce          1 Chambre
# 455        440 000 DH     84 m²            1 Pièce         2 Chambres
{'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 257  {'Climatisation': 'Climatisation', 'Double vit...
# 258  {'Ascenseur': 'Ascenseur', 'Concierge': 'Conci...
# 259     {'Garage': 'Garage', 'Ascenseur': 'Ascenseur'}
# 260     {'Piscine': 'Piscine', 'Sécurité': 'Sécurité'}
# 261  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 262                                                 {}
# 263  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 264                                                 {}
# 265  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 266  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 267  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 268  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 269  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 270  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 271  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 272                                                 {}
# 273                                                 {}
# 274                                                 {}
# 275                               {'Jardin': 'Jardin'}
# 276  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 277                                                 {}
# 278                                                 {}
# 279  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 280  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 281  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 282  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 283  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 284  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 285                                                 {}
# 286                             {'Piscine': 'Piscine'}
# 287  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 288  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 289  {'Ascenseur': 'Ascenseur', 'Concierge': 'Conci...
# 290  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 291  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 292  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 293  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 294  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 295  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 296  {'Terrasse': 'Terrasse', 'Piscine': 'Piscine',...
# 297  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 298  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 299  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 300  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 301  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 302  {'Ascenseur': 'Ascenseur', 'Climatisation': 'C...
# 303                             {'Piscine': 'Piscine'}
# 304                             {'Piscine': 'Piscine'}
# 305                                                 {}
# 306  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 307  {'Piscine': 'Piscine', 'Climatisation': 'Clima...
# 308  {'Piscine': 'Piscine', 'Concierge': 'Concierge...
# 309  {'Piscine': 'Piscine', 'Climatisation': 'Clima...
# 310     {'Terrasse': 'Terrasse', 'Piscine': 'Piscine'}
# 311  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 312  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 313  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 314  {'Jardin': 'Jardin', 'Garage': 'Garage', 'Asce...
# 315  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 316  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 317  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 318  {'Piscine': 'Piscine', 'Cuisine équipée': 'Cui...
# 319  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 320  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 321  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 322  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 323  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 324  {'Piscine': 'Piscine', 'Climatisation': 'Clima...
# 325  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 326  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 327  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 328  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 329                                                 {}
# 330                             {'Piscine': 'Piscine'}
# 331                             {'Piscine': 'Piscine'}
# 332                             {'Piscine': 'Piscine'}
# 333                             {'Piscine': 'Piscine'}
# 334                             {'Piscine': 'Piscine'}
# 335                             {'Piscine': 'Piscine'}
# 336  {'Climatisation': 'Climatisation', 'Cuisine éq...
# 337  {'Climatisation': 'Climatisation', 'Cuisine éq...
# 338                               {'Garage': 'Garage'}
# 339  {'Jardin': 'Jardin', 'Garage': 'Garage', 'Asce...
# 340  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 341                                                 {}
# 342  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 343  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 344  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 345                                                 {}
# 346  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 347  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 348  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 349  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 350                         {'Ascenseur': 'Ascenseur'}
# 351  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 352                               {'Garage': 'Garage'}
# 353                                                 {}
# 354                                                 {}
# 355                                                 {}
# 356                                                 {}
# 357                                                 {}
# 358  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 359  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 360                                                 {}
# 361                                                 {}
# 362  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 363  {'Climatisation': 'Climatisation', 'Cuisine éq...
# 364  {'Climatisation': 'Climatisation', 'Cuisine éq...
# 365  {'Climatisation': 'Climatisation', 'Cuisine éq...
# 366  {'Climatisation': 'Climatisation', 'Cuisine éq...
# 367  {'Climatisation': 'Climatisation', 'Cuisine éq...
# 368  {'Climatisation': 'Climatisation', 'Cuisine éq...
# 369  {'Climatisation': 'Climatisation', 'Cuisine éq...
# 370  {'Climatisation': 'Climatisation', 'Cuisine éq...
# 371     {'Terrasse': 'Terrasse', 'Piscine': 'Piscine'}
# 372  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 373  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 374                                                 {}
# 375  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 376                           {'Sécurité': 'Sécurité'}
# 377       {'Terrasse': 'Terrasse', 'Garage': 'Garage'}
# 378  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 379  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 380                                                 {}
# 381                                                 {}
# 382  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 383                                                 {}
# 384                                                 {}
# 385     {'Terrasse': 'Terrasse', 'Piscine': 'Piscine'}
# 386  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 387                                                 {}
# 388  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 389  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 390  {'Ascenseur': 'Ascenseur', 'Cuisine équipée': ...
# 391                                                 {}
# 392                               {'Garage': 'Garage'}
# 393  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 394  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 395                                                 {}
# 396  {'Climatisation': 'Climatisation', 'Cuisine éq...
# 397  {'Climatisation': 'Climatisation', 'Cuisine éq...
# 398  {'Piscine': 'Piscine', 'Ascenseur': 'Ascenseur...
# 399  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 400  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 401  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 402  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 403  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 404                           {'Sécurité': 'Sécurité'}
# 405  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 406  {'Garage': 'Garage', 'Concierge': 'Concierge',...
# 407                                                 {}
# 408  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 409  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 410  {'Climatisation': 'Climatisation', 'Double vit...
# 411  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 412                             {'Piscine': 'Piscine'}
# 413     {'Terrasse': 'Terrasse', 'Piscine': 'Piscine'}
# 414                           {'Sécurité': 'Sécurité'}
# 415  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 416  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 417  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 418                         {'Ascenseur': 'Ascenseur'}
# 419                               {'Garage': 'Garage'}
# 420  {'Ascenseur': 'Ascenseur', 'Cuisine équipée': ...
# 421                                                 {}
# 422  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 423  {'Garage': 'Garage', 'Cuisine équipée': 'Cuisi...
# 424                                                 {}
# 425     {'Garage': 'Garage', 'Ascenseur': 'Ascenseur'}
# 426  {'Ascenseur': 'Ascenseur', 'Jardin': 'Jardin',...
# 427                                                 {}
# 428                                                 {}
# 429  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 430  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 431  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 432  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 433  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 434  {'Ascenseur': 'Ascenseur', 'Concierge': 'Conci...
# 435  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 436  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 437  {'Ascenseur': 'Ascenseur', 'Concierge': 'Conci...
# 438                                                 {}
# 439     {'Piscine': 'Piscine', 'Sécurité': 'Sécurité'}
# 440  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 441  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 442                                                 {}
# 443  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 444  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 445     {'Piscine': 'Piscine', 'Sécurité': 'Sécurité'}
# 446  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 447  {'Climatisation': 'Climatisation', 'Double vit...
# 448  {'Climatisation': 'Climatisation', 'Chauffage ...
# 449                                                 {}
# 450     {'Piscine': 'Piscine', 'Sécurité': 'Sécurité'}
# 451  {'Terrasse': 'Terrasse', 'Piscine': 'Piscine',...
# 452  {'Ascenseur': 'Ascenseur', 'Cuisine équipée': ...
# 453             {'Cuisine équipée': 'Cuisine équipée'}
# 454     {'Garage': 'Garage', 'Ascenseur': 'Ascenseur'}
# 455                                                 {}
# 456  {'Ascenseur': 'Ascenseur', 'Salon Marocain': '...
# 457       {'Terrasse': 'Terrasse', 'Garage': 'Garage'}
# 458             {'Cuisine équipée': 'Cuisine équipée'}
# 459  {'Chauffage central': 'Chauffage central', 'Sé...
# 460  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 461                                                 {}
# 462  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 463  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 464  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 465  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 466  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 467  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 468  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 469  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 470  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 471  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 472  {'Piscine': 'Piscine', 'Climatisation': 'Clima...
# 473                                                 {}
# 474  {'Jardin': 'Jardin', 'Garage': 'Garage', 'Asce...
# 475  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 476  {'Climatisation': 'Climatisation', 'Double vit...
# 477  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 478  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
# 479  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 480  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 481  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 482  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 483  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 484  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 485                                                 {}
# 486  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 487                                                 {}
# 488  {'Garage': 'Garage', 'Ascenseur': 'Ascenseur',...
# 489                                                 {}
# 490             {'Cuisine équipée': 'Cuisine équipée'}
# 491             {'Cuisine équipée': 'Cuisine équipée'}
# 492                               {'Garage': 'Garage'}
# 493  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 494  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 495  {'Terrasse': 'Terrasse', 'Ascenseur': 'Ascense...
# 496  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 497  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...
# 498  {'Ascenseur': 'Ascenseur', 'Concierge': 'Conci...
# 499  {'Terrasse': 'Terrasse', 'Garage': 'Garage', '...

# %%
# Importation des bibliothèques nécessaires pour le scraping avec Selenium

# Permet d'utiliser le WebDriver pour contrôler un navigateur web
from selenium import webdriver 
# Permet de localiser des éléments sur la page web
from selenium.webdriver.common.by import By
# Permet d'ajouter des pauses dans le script (utile pour éviter des erreurs dues à des actions trop rapides)
import time
# Permet de travailler avec des DataFrames (utile pour structurer les données collectées)
import pandas as pd  


path_chomedriver =  "/home/marwane/mlops-projects/morocco-appartements-price/chromedriver_linux64/chromedriver" 

# Création d'une instance de ChromeOptions pour personnaliser les options du navigateur
options = webdriver.ChromeOptions()

# Ajout d'une option pour exclure les messages de logging de Chrome
options.add_experimental_option('excludeSwitches', ['enable-logging'])
  
# si vous ajouter le "executable_path" dans le cas au vous utilisez un ancie version
#driver = webdriver.Chrome(executable_path=path_chomedriver, options=options)
driver = webdriver.Chrome(options=options)


def scrape_info(start_link,end_link, num_file):
    list_informations = []
    for i in range(start_link, end_link):

        url = immobier_links[i]

        time.sleep(2)
        
        driver.get(url)

        try:
            price = driver.find_element(By.CLASS_NAME, "orangeTit").text
        except:
            price = None
        
        try:
            # Assuming appartement_features.find_elements(By.CLASS_NAME, "adDetailFeature") returns a list of elements
            elements = driver.find_elements(By.CLASS_NAME, "adDetailFeature")

            # Initialize a list of None values (default)
            features = [None, None, None, None]

            # Loop through the available elements and assign them to the corresponding feature in the list
            for i in range(min(len(elements), 4)):  # Ensure we do not exceed 4 elements
                features[i] = elements[i].text

                # Now, you can assign each value to the respective variables
                surface, piece, rooms, bathroom = features
        except:
            surface, piece, rooms, bathroom = [None, None, None, None]

        try:
            address = driver.find_element(By.CLASS_NAME, "greyTit").text
        except:
            address = None

        try:
            description = driver.find_element(By.CLASS_NAME, "blockProp").text 
        except:
            description = None

        try:
            more_features_1 = driver.find_elements(By.CLASS_NAME, "adMainFeature")
            more_features_1_dict = {}
            for i in range(len(more_features_1)): 
                more_features_1_dict[f"{more_features_1[i].text}"] = f"{more_features_1[i].text}"
        except:
            more_features_1 = None

        try:
            more_features_2 = driver.find_elements(By.CLASS_NAME, "adFeature")
            more_features_2_dict = {}
            for i in range(len(more_features_2)): 
                more_features_2_dict[f"{more_features_2[i].text}"] = f"{more_features_2[i].text}"
        except:
            more_features_2 = None

        values = [price, surface, piece, rooms, bathroom, address, description, more_features_1_dict, more_features_2_dict]
        list_informations.append(values)


    features = ["price", "surface", "piece", "rooms", "bathroom", "address", "description", "more_features_1_dict", "more_features_2_dict"]
    df = pd.DataFrame(data=list_informations, columns=features)
    df.to_csv(f"moroccan-immobilier-houses-price-{num_file}.csv", index=False)
    
    return df

df_link = pd.read_csv("/home/marwane/mlops-projects/morocco-appartements-price/link-file.csv")
immobier_links = df_link.link.values.tolist()


## Call funtion
time.sleep(60)
#df2 = scrape_info(start_link=6000 ,end_link=7000 , num_file=11) #file9=1000 #file10=1000
df3 = scrape_info(start_link=7000 ,end_link=8675 , num_file=12) #file9=1000 #file10=1000

# %%
len(immobier_links)
# Out:
# 8675

# %%
df3.shape
# Out:
# (1675, 9)

# %%
time.sleep(100)
df2 = scrape_info(start_link=3500 ,end_link=4000 , num_file=8)

# %%
df2.shape
# Out:
# (1000, 9)

# %%
# Rescrape this part
df4 = scrape_info(start_link=1500 ,end_link=2000 , num_file=4)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File ~/anaconda3/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File ~/anaconda3/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~/anaconda3/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File ~/anaconda3/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     707 try:
# --> 708     return self._sock.recv_into(b)
#     709 except timeout:
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Rescrape this part
# ----> 2 df4 = scrape_info(start_link=1500 ,end_link=2000 , num_file=4)
#
# Cell In[1], line 34, in scrape_info(start_link, end_link, num_file)
#      30 url = immobier_links[i]
#      32 time.sleep(2)
# ---> 34 driver.get(url)
#      36 try:
#      37     price = driver.find_element(By.CLASS_NAME, "orangeTit").text
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:393, in WebDriver.get(self, url)
#     391 def get(self, url: str) -> None:
#     392     """Loads a web page in the current browser session."""
# --> 393     self.execute(Command.GET, {"url": url})
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:382, in WebDriver.execute(self, driver_command, params)
#     379     elif "sessionId" not in params:
#     380         params["sessionId"] = self.session_id
# --> 382 response = self.command_executor.execute(driver_command, params)
#     383 if response:
#     384     self.error_handler.check_response(response)
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/selenium/webdriver/remote/remote_connection.py:404, in RemoteConnection.execute(self, command, params)
#     402 trimmed = self._trim_large_entries(params)
#     403 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 404 return self._request(command_info[0], url, body=data)
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/selenium/webdriver/remote/remote_connection.py:428, in RemoteConnection._request(self, method, url, body)
#     425     body = None
#     427 if self._client_config.keep_alive:
# --> 428     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     429     statuscode = response.status
#     430 else:
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/_request_methods.py:143, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     135     return self.request_encode_url(
#     136         method,
#     137         url,
#    (...)
#     140         **urlopen_kw,
#     141     )
#     142 else:
# --> 143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/_request_methods.py:278, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     274     extra_kw["headers"].setdefault("Content-Type", content_type)
#     276 extra_kw.update(urlopen_kw)
# --> 278 return self.urlopen(method, url, **extra_kw)
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840 elif isinstance(new_e, (OSError, HTTPException)):
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#     848 # Keep track of the error for the retry warning.
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     471 elif error and self._is_read_error(error):
#     472     # Read retry?
#     473     if read is False or method is None or not self._is_method_retryable(method):
# --> 474         raise reraise(type(error), error, _stacktrace)
#     475     elif read is not None:
#     476         read -= 1
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      37     if value.__traceback__ is not tb:
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#      41     value = None  # type: ignore[assignment]
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#     541 # Set properties that are used by the pooling layer.
#
# File ~/mlops-projects/morocco-appartements-price/morocco/lib/python3.12/site-packages/urllib3/connectionpool.py:369, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 """Is the error actually a timeout? Will raise a ReadTimeout or pass"""
#     368 if isinstance(err, SocketTimeout):
# --> 369     raise ReadTimeoutError(
#     370         self, url, f"Read timed out. (read timeout={timeout_value})"
#     371     ) from err
#     373 # See the above comment about EAGAIN in Python 3.
#     374 if hasattr(err, "errno") and err.errno in _blocking_errnos:
#
# ReadTimeoutError: HTTPConnectionPool(host='localhost', port=52187): Read timed out. (read timeout=120)

# %%
# Importation des bibliothèques nécessaires pour le scraping avec Selenium

# Permet d'utiliser le WebDriver pour contrôler un navigateur web
from selenium import webdriver 
# Permet de localiser des éléments sur la page web
from selenium.webdriver.common.by import By
# Permet d'ajouter des pauses dans le script (utile pour éviter des erreurs dues à des actions trop rapides)
import time
# Permet de travailler avec des DataFrames (utile pour structurer les données collectées)
import pandas as pd  


path_chomedriver =  "/home/marwane/mlops-projects/morocco-appartements-price/chromedriver_linux64/chromedriver" 

# Création d'une instance de ChromeOptions pour personnaliser les options du navigateur
options = webdriver.ChromeOptions()

# Ajout d'une option pour exclure les messages de logging de Chrome
options.add_experimental_option('excludeSwitches', ['enable-logging'])
  
# si vous ajouter le "executable_path" dans le cas au vous utilisez un ancie version
#driver = webdriver.Chrome(executable_path=path_chomedriver, options=options)
driver = webdriver.Chrome(options=options)


def scrape_info(start_link,end_link, num_file):
    list_informations = []
    for i in range(start_link, end_link):

        url = immobier_links[i]

        time.sleep(2)
        try:
            driver.get(url)

            try:
                price = driver.find_element(By.CLASS_NAME, "orangeTit").text
            except:
                price = None
            
            try:
                # Assuming appartement_features.find_elements(By.CLASS_NAME, "adDetailFeature") returns a list of elements
                elements = driver.find_elements(By.CLASS_NAME, "adDetailFeature")

                # Initialize a list of None values (default)
                features = [None, None, None, None]

                # Loop through the available elements and assign them to the corresponding feature in the list
                for i in range(min(len(elements), 4)):  # Ensure we do not exceed 4 elements
                    features[i] = elements[i].text

                    # Now, you can assign each value to the respective variables
                    surface, piece, rooms, bathroom = features
            except:
                surface, piece, rooms, bathroom = [None, None, None, None]
    
            try:
                address = driver.find_element(By.CLASS_NAME, "greyTit").text
            except:
                address = None

            try:
                description = driver.find_element(By.CLASS_NAME, "blockProp").text 
            except:
                description = None

            try:
                more_features_1 = driver.find_elements(By.CLASS_NAME, "adMainFeature")
                more_features_1_dict = {}
                for i in range(len(more_features_1)): 
                    more_features_1_dict[f"{more_features_1[i].text}"] = f"{more_features_1[i].text}"
            except:
                more_features_1 = None

            try:
                more_features_2 = driver.find_elements(By.CLASS_NAME, "adFeature")
                more_features_2_dict = {}
                for i in range(len(more_features_2)): 
                    more_features_2_dict[f"{more_features_2[i].text}"] = f"{more_features_2[i].text}"
            except:
                more_features_2 = None

            values = [price, surface, piece, rooms, bathroom, address, description, more_features_1_dict, more_features_2_dict]
            list_informations.append(values)

        except Exception as e:
            continue

        features = ["price", "surface", "piece", "rooms", "bathroom", "address", "description", "more_features_1_dict", "more_features_2_dict"]
        df = pd.DataFrame(data=list_informations, columns=features)
        df.to_csv(f"moroccan-immobilier-houses-price-{num_file}.csv", index=False)
    
    return df

df_link = pd.read_csv("/home/marwane/mlops-projects/morocco-appartements-price/link-file.csv")
immobier_links = df_link.link.values.tolist()


## Call funtion
# Repeat this scraping
#df2 = scrape_info(start_link=1500 ,end_link=2000 , num_file=4)

# %%
df2.shape
# Out:
# (178, 9)

# %%
df2.shape
# Out:
# (178, 9)

# %%
df2.head()
# Out:
#           price surface     piece       rooms           bathroom  \
# 0  4 350 000 DH  270 m²  4 Pièces  3 Chambres  3 Salles de bains
# 1  1 045 000 DH   87 m²  3 Pièces  2 Chambres  2 Salles de bains
# 2  1 350 000 DH   73 m²  2 Pièces   1 Chambre    1 Salle de bain
# 3  1 100 000 DH   75 m²  3 Pièces  2 Chambres    1 Salle de bain
# 4  2 700 000 DH   60 m²  2 Pièces   1 Chambre    1 Salle de bain
#
#                           address  \
# 0           Ain Diab à Casablanca
# 1    Bourgogne Ouest à Casablanca
# 2    Bourgogne Ouest à Casablanca
# 3             Maârif à Casablanca
# 4  Casablanca Marina à Casablanca
#
#                                          description  \
# 0  Superbe appartement à vendre\nSaigh Immo met e...
# 1  Bel appartement à vendre\nSaigh Immo met en ve...
# 2  Studio neuf sans vis à vis à vendre\nSaigh Imm...
# 3  Bel appartement sans vis à vis à vendre\nSaigh...
# 4  Studio moderne à vendre vue sur mer\nSaigh Imm...
#
#                                 more_features_1_dict  \
# 0  {'Type de bien
# Appartement': 'Type de bien
# App...
# 1  {'Type de bien
# Appartement': 'Type de bien
# App...
# 2  {'Type de bien
# Appartement': 'Type de bien
# App...
# 3  {'Type de bien
# Appartement': 'Type de bien
# App...
# 4  {'Type de bien
# Appartement': 'Type de bien
# App...
#
#                                 more_features_2_dict
# 0                           {'Sécurité': 'Sécurité'}
# 1       {'Garage': 'Garage', 'Sécurité': 'Sécurité'}
# 2                                                 {}
# 3                                                 {}
# 4  {'Jardin': 'Jardin', 'Terrasse': 'Terrasse', '...
